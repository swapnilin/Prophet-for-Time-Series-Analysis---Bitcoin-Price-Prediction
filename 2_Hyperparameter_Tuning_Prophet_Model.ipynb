# %% [markdown]
# #Intro

# %% [markdown]
# ## Hyperparameter tuning and regularization for time series model using prophet in Python.
#
# Contents:
#
#
# * Explore various hyperparameters for a prophet time series model.
# * What hyperparameters to tune, and what hyperparameters are better not to be tuned.
# * Among all the hyperparameters that should be tuned, what hyperparameters should be tuned automatically vs. manually.
# * How are hyperparameter tunings related to regularization.
# * How does data transformation impact the model performance.

# %% [markdown]
# # Overview of All the Hyperparameters for a Prophet Model

# %% [markdown]
# We will categorize the hyperparameters into three groups:
#
# * The first group contains hyperparameters that are suitable for automatic tuning. We can specify a list of values and do a grid search for the best value combination.
# * The second group contains hyperparameters that are suitable for manual tuning. A human needs to make a judgment on what hyperparameter value to use based on knowledge about data and business.
# * The third group contains the hyperparameters that are better left untuned with the default values.

# %% [markdown]
# ## Group 1: Hyperparameters Suitable for Automatic Tuning

# %% [markdown]
# There are four hyperparameters that are suitable to be tuned automatically using grid search.
# * `changepoint_prior_scale` is probably the most impactful parameter according to the Prophet documentation. It determines the scale of the change at the time series trend change point. It is an L1 LASSO regularization penalty term. To learn more about regularization, please refer to my previous tutorial [LASSO (L1) Vs Ridge (L2) Vs Elastic Net Regularization For Classification Model](https://medium.com/towards-artificial-intelligence/lasso-l1-vs-ridge-l2-vs-elastic-net-regularization-for-classification-model-409c3d86f6e9)
#   * When the scale is too small, the trend does not change much at the change point, and the model tends to underfit. This is because the variance caused by the trend change is likely to be considered as noise with a small `changepoint_prior_scale` value.
#   * When the scale is too large, the trend changes a lot at the change point, and the model tends to overfit. The variance caused by noise is considered to be part of the trend.
#   * The default value for `changepoint_prior_scale` is 0.05, and the recommended tuning range is 0.001 to 0.5. This hyperparameter is usually tuned on a log scale.
#
# * `seasonality_prior_scale` controls the magnitude of the seasonality fluctuation. It is an L2 Ridge regularization penalty term.
#   * When the scale is too small, the magnitude of the seasonality shrinks to a very small value.
#   * When the scale is too large, the magnitude of the seasonality allows very large fluctuations.
#   * The default value for `seasonality_prior_scale` is 10, meaning that no regularization is applied. The recommended tuning range is 0.01 to 10, where a smaller value corresponds to a smaller magnitude of seasonality. This hyperparameter is usually tuned on a log scale.
#
# * `holidays_prior_scale` determines the scale of holiday effects, and is very similar to the `seasonality_prior_scale`. The default value is 10, meaning that no regularization is applied. The recommended tuning range is 0.01 to 10, where a smaller value corresponds to a smaller magnitude of holidays.
#
# * `seasonality_mode` has two options, `additive` and `multiplicative`.
#   * The additive model adds trend, seasonality, and other effects together when making predictions. It is appropriate for the time series models with relatively constant seasonal variation over time.
#   * The multiplicative model multiplies trend, seasonality, and other effects together when making predictions. It is appropriate for the time series models with increasing or decreasing seasonal variation over time.

# %% [markdown]
# ## Group 2: Hyperparameters Suitable for Manual Tuning

# %% [markdown]
# Some hyperparameters need to be evaluated by a human-based on business knowledge or data observations for manual tuning.
# * `changepoint_range` is a value between 0 and 1 indicating the percentage of historical data that allow a trend change.
#   * The default value is 0.8, meaning that the first 80% of the data allows trend changes, and the last 20% of the data does not allow a trend change. This is because there are not enough data at the end of the time series to identify a trend change with confidence.
#   * The person who builds the model can increase or decrease the value manually by examining the time series shape and model performance for the last 20% of data.
#
# * `growth` has two options, `linear` and `logistic`. The default value is `linear`, and it can be manually changed to `logistic` if there is a known growth saturating point.
#
# * `changepoints` manually specifying the dates of changepoints. The default value is `None`, which allows the model to automatically identify and place the change points on the trend. However, if there are any known events such as the rebranding of the business, the corresponding date can be manually added.
#
# * `yearly_seasonality` has three options, `auto`, `True`, and `False`. The default is `auto`, which automatically turns the yearly seasonality on when there are at least two cycles of data.
#   * We can manually set `yearly_seasonality` to be `True` to force the yearly seasonality if there are less than two years of data.
#   * `yearly_seasonality` is usually not set to `False`, because it's more effective to leave it on and turn down the seasonal effects by tuning `seasonality_prior_scale`[2].
#
# * `weekly_seasonality` and `daily_seasonality` can be handled in the same way as the `yearly_seasonality`.
#
# * `holidays` takes in a dataframe with specified holidays and special events. We can manually include or exclude holidays or events, or change the number of days impacted by the holiday to tune this hyperparameter. The magnitude of the holiday effects should be tuned by `holidays_prior_scale`.

# %% [markdown]
# ## Group 3: Hyperparameters best as Default

# %% [markdown]
# There are five hyperparameters that should not be tuned.
# * `n_changepoints` is the number of changepoints on the trend. The default value is 25. Rather than increasing or decreasing the number of changepoints, the prophet documentation[2] suggested focusing on increasing or decreasing the flexibility at those trend changes, which is done with `changepoint_prior_scale`.
#
# * `interval_width` determines the uncertainty interval for the predictions. The default value is 0.8, meaning that the prediction upper bound `yhat_upper` and the prediction lower bound `yhat_lower` are based on the 80% uncertainty interval. `interval_width` does not impact the model prediction, so there is no need to tune this hyperparameter.
#
# * `uncertainty_samples` is the number of samples used for uncertainty interval calculation. The default value is 1000, and increasing the value decreases the variance of the uncertainty interval. This hyperparameter does not impact the model prediction, so there is no need to tune it.
#
# * `mcmc_samples` is an integer that determines if the model uses a full Bayesian inference or a Maximum a Posterior (MAP) for model training and prediction.
#   * When it's greater than 0, a full Bayesian inference with the specified number of MCMC samples will be used. Bayesian inference usually needs at least 1000 samples to get reasonable results.
#   * When it equals to 0, a Maximum a Posterior (MAP) estimation will be used. The default value for `mcmc_samples` is 0, indicating that Maximum a Posterior (MAP) estimation is used by default. The prophet documentation suggests leaving this hyperparameter unchanged[2].
#
# * `stan_backend` needs to be specified when both `pystan` and `cmdstanpy` backends are set up. This hyperparameter does not impact model training and prediction, so there is no need to tune it.

# %% [markdown]
# # Step 1: Install and Import Libraries

# %%
# Install libraries
#!pip install yfinance prophet

# %%
# For data processing
import pandas as pd
import numpy as np

# To get time series data
import yfinance as yf

# import prophet
from prophet import Prophet

# For visualization
import seaborn as sns
import matplotlib.pyplot as plt

# For hyperparameter tuning
import itertools
from prophet.diagnostics import cross_validation, performance_metrics

# %% [markdown]
# # Step 2: Pull Data

# %%
# Data start date
start_date = '2021-01-01'

# Data end date
end_date = '2023-06-01' # yfinance excludes the end date, so we need to add one day to the last day of data

# %% [markdown]
# The goal of the time series model is to predict the closing price of Google's stock, so Google's ticker `GOOG` is used for pulling the data.
#
# Prophet requires at least two columns as inputs: a `ds` column and a `y` column.
# * The `ds` column has the time information. Currently we have the date as the index, so we reset the index and rename `date` to `ds`.
# * The y column has the time series values. In this example, because we are predicting Google's closing price, the column name for the price is changed to `y`.

# %%
# Pull close data from Yahoo Finance for the list of tickers
ticker_list = ['GOOG']
data = yf.download(ticker_list, start=start_date, end=end_date)[['Close']]

# Change column names
data = data.reset_index()
data.columns = ['ds', 'y']

# Take a look at the data
data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#           ds          y
# 0 2021-01-04  86.412003
# 1 2021-01-05  87.045998
# 2 2021-01-06  86.764503
# 3 2021-01-07  89.362503
# 4 2021-01-08  90.360497

# %%
data.tail()
# Out:
#             ds           y
# 601 2023-05-24  121.639999
# 602 2023-05-25  124.349998
# 603 2023-05-26  125.430000
# 604 2023-05-30  124.639999
# 605 2023-05-31  123.370003

# %% [markdown]
# Using `.info`, we can see that the dataset has 606 records and there are no missing values.

# %%
# Data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606 entries, 0 to 605
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      606 non-null    datetime64[ns]
#  1   y       606 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 9.6 KB

# %% [markdown]
# Next, let's visualize the closing prices of the two tickers using `seaborn`, and add the legend to the plot using `matplotlib`.

# %%
# Visualize data using seaborn
sns.set(rc={'figure.figsize':(12,8)})
sns.lineplot(x=data['ds'], y=data['y'])
plt.legend(['Google'])

# %% [markdown]
# # Step 3: Baseline Model Using Default Hyperparameters

# %% [markdown]
# First, let's build a baseline model using the default prophet hyperparameters.

# %%
# Initiate the model
baseline_model = Prophet()

# Fit the model on the training dataset
baseline_model.fit(data)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/zhj_trs5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/stkjb277.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25629', 'data', 'file=/tmp/tmpy5nrbzj0/zhj_trs5.json', 'init=/tmp/tmpy5nrbzj0/stkjb277.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelqn7cndgb/prophet_model-20231030005423.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 00:54:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 00:54:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# records for the year of 2021
data[(data['ds']>='2021-01-04') & (data['ds']<='2022-01-01')].shape
# Out:
# (252, 2)

# %% [markdown]
# Prophet automatically fits daily, weekly, and yearly seasonalities if the time series is more than two cycles long.
#
# * The model information shows that the daily seasonality is disabled because we do not have sub-daily time series.
#
# * The yearly seasonality is disabled although we have two years of data because there are no stock price data on holidays and weekends, **so we have less than 365 data points for each year.**

# %% [markdown]
# Next, let's do cross-validation for the baseline model to get the model performance. Prophet has a `cross_validation` function to automate the comparison between the actual and the predicted values.
# * `model=baseline_model` specifies the model name.
# * `initial='200 days'` means the initial model will be trained on the first 200 days of data.
# * `period='30 days'` means 30 days will be added to the training dataset for each additional model.
# * `horizon = '30 days'` means that the model forecasts the next 30 days. When only `horizon` is given, Prophet defaults `initial` to be triple the `horizon`, and `period` to be half of the `horizon`.
# * `parallel="processes"` enables parallel processing for cross-validation. When the parallel cross-validation can be done on a single machine, "processes" provide the highest performance. For larger problems, `dask` can be used to do cross-validation on multiple machines.

# %%
# Cross validation
baseline_model_cv = cross_validation(model=baseline_model, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")

# %%
baseline_model_cv.head()
# Out:
#           ds        yhat  yhat_lower  yhat_upper           y     cutoff
# 0 2021-08-10  137.541565  135.324340  140.039823  138.096497 2021-08-09
# 1 2021-08-11  137.923517  135.540653  140.195308  137.689499 2021-08-09
# 2 2021-08-12  138.486621  136.098054  140.842377  138.389496 2021-08-09
# 3 2021-08-13  139.108443  136.538256  141.326940  138.406006 2021-08-09
# 4 2021-08-16  139.980662  137.597729  142.332520  138.916000 2021-08-09

# %% [markdown]
# Based on the output from the cross-validation, we can get the model performance using the method `performance_metrics`.
# * The model performance metrics are calculated using a rolling window. The average performance metrics values are calculated for each value of the horizon. Since we have the horizon value of 30 days, there will be 30 average values, one for each day.
# * `rolling_window` determines the window size, which is the percentage of forecasted data points to include in the calculation.
#   * `rolling_window=0` computes performance metrics separately for each horizon.
#   * `rolling_window=0.1` is the default value, which computes performance metrics using about 10% of the predictions in each window.
#   * `rolling_window=1` computes performance metrics using all the forecasted data. We are using `rolling_window=1` in this tutorial. to get a single performance metric number.
#   * `rolling_window<0` computes each data point without averaging (i.e., `MSE` will actually be a squared error with no mean)[3]

# %%
# Model performance metrics
baseline_model_p = performance_metrics(baseline_model_cv, rolling_window=1)
baseline_model_p.head()
# Out:
#   horizon         mse       rmse        mae      mape     mdape     smape  \
# 0 30 days  261.422581  16.168568  10.285173  0.083541  0.056043  0.080921
#
#    coverage
# 0  0.307692

# %% [markdown]
# Prophet provides six commonly used performance metrics:
# * Mean Squared Error(MSE) sums up the squared difference between actual and prediction and is divided by the number of predictions.
# * Root Mean Square Error(RMSE) takes the square root of MSE.
# * Mean Absolute Error(MAE) sums up the absolute difference between actual and prediction and is divided by the number of predictions.
# * Mean Absolute Percentage Error(MAPE) sums up the absolute percentage difference between actual and prediction and is divided by the number of predictions. MAPE is independent of the magnitude of data, so it can be used to compare different forecasts. But it's undefined when the actual value is zero.
# * Median Absolute Percentage Error(MDAPE) is similar to MAPE. The difference is that it calculates the median instead of taking the average of the absolute percentage difference.
# * Symmetric Mean Absolute Percentage Error(SMAPE) is similar to MAPE. The difference is that when calculating absolute percentage error, the denominator is the actual value for MAPE and the average of the actual and predicted value for SMAPE.
#
# We can see that the baseline model using default hyperparameters has **8.35% Mean Absolute Percentage Error (MAPE)**, meaning that the predictions are 8.35% off the actual values.

# %%
# Get the performance metric value
baseline_model_p['mape'].values[0]
# Out:
# 0.08354112008360577

# %% [markdown]
# # Step 4: Models with Manual Hyperparameter Changes

# %% [markdown]
# * `changepoint_range` will be increased from 0.8 to 0.9 to see if there is a trend change near the end of the time series. This is because the shape of the time series seems to flatter starting around January of 2023 based on observation.
#
# * `growth` is kept at the default value `linear` because there is no saturating point for the stock price data.
#
# * `changepoints` is kept at the default value is `None`, which allows the model to automatically identify and place the change points on the trend. This is because there are not any known big events that are likely to impact the Google stock prices in the time range used for the model.
#
# * `yearly_seasonality` is kept at the automated value of `False` because we do not have more than 2 cycles of yearly data for the model training.
#
# * `weekly_seasonality` is kept at the automated value of `True` because we have more than 2 cycles of weekly data.
#
# * `daily_seasonality` is kept at the automated value of `False` because we do not have sub-daily data.
#
# * `holidays` takes in a dataframe with specified holidays and special events. We can manually included two special events, COVID start and Super Bowl.
#
# The manually changed hyperparameters will be evaluated one by one. If the change improves the model performance, we will keep the change, otherwise, we will switch back to the default values.

# %% [markdown]
# ## Step 4.1: Change Point Range

# %% [markdown]
# Firstly, let's increase `changepoint_range` from 0.8 to 0.9 to see if there is a trend change near the end of the time series.

# %%
# Initiate the model
manual_model = Prophet(changepoint_range=0.9)

# Fit the model on the training dataset
manual_model.fit(data)

# Cross validation
manual_model_cv = cross_validation(manual_model, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")

# Model performance metrics
manual_model_p = performance_metrics(manual_model_cv, rolling_window=1)
manual_model_p['mape'].values[0]
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/25h66bfs.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ha683rdt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68067', 'data', 'file=/tmp/tmpy5nrbzj0/25h66bfs.json', 'init=/tmp/tmpy5nrbzj0/ha683rdt.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelyc_obibu/prophet_model-20231030014425.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 22 forecasts with cutoffs between 2021-08-09 00:00:00 and 2023-05-01 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x78b81b819ae0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/tcfy15rb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/mfpjz58g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/jhtsyrfi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/lnsn_yhr.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1014', 'data', 'file=/tmp/tmpy5nrbzj0/mfpjz58g.json', 'init=/tmp/tmpy5nrbzj0/jhtsyrfi.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model9tl3cq5i/prophet_model-20231030014425.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98397', 'data', 'file=/tmp/tmpy5nrbzj0/tcfy15rb.json', 'init=/tmp/tmpy5nrbzj0/lnsn_yhr.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelo1uasogo/prophet_model-20231030014425.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:44:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0ytx1p3l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/kap3p6p1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11971', 'data', 'file=/tmp/tmpy5nrbzj0/0ytx1p3l.json', 'init=/tmp/tmpy5nrbzj0/kap3p6p1.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model8nhuga59/prophet_model-20231030014426.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:26 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/8jwsfi68.json
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_i66jj_p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88935', 'data', 'file=/tmp/tmpy5nrbzj0/8jwsfi68.json', 'init=/tmp/tmpy5nrbzj0/_i66jj_p.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelazhkjqsa/prophet_model-20231030014426.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/d0jiu9qy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/n6o8kh3c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/6a0uk_6p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83307', 'data', 'file=/tmp/tmpy5nrbzj0/d0jiu9qy.json', 'init=/tmp/tmpy5nrbzj0/6a0uk_6p.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modela0nu5cgn/prophet_model-20231030014426.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/uxv_be_3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25063', 'data', 'file=/tmp/tmpy5nrbzj0/n6o8kh3c.json', 'init=/tmp/tmpy5nrbzj0/uxv_be_3.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model3_a2fmtk/prophet_model-20231030014426.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:44:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/cgo_wmsp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/pd6a7wct.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/h_3nqa_j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ahfdomec.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50970', 'data', 'file=/tmp/tmpy5nrbzj0/cgo_wmsp.json', 'init=/tmp/tmpy5nrbzj0/h_3nqa_j.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model949__qj6/prophet_model-20231030014426.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:idx 0
# 01:44:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89596', 'data', 'file=/tmp/tmpy5nrbzj0/pd6a7wct.json', 'init=/tmp/tmpy5nrbzj0/ahfdomec.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model_wo1y0_r/prophet_model-20231030014426.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:27 - cmdstanpy - INFO - Chain [1] done processing
# 01:44:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:44:27 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/wt0woet3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/7txxy3nf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43510', 'data', 'file=/tmp/tmpy5nrbzj0/wt0woet3.json', 'init=/tmp/tmpy5nrbzj0/7txxy3nf.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modello6bw42v/prophet_model-20231030014427.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:44:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/3kdam_pk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/l4ep64u7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42303', 'data', 'file=/tmp/tmpy5nrbzj0/3kdam_pk.json', 'init=/tmp/tmpy5nrbzj0/l4ep64u7.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelvcobcgl7/prophet_model-20231030014427.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/wtvrb_9u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/b99fim6g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11542', 'data', 'file=/tmp/tmpy5nrbzj0/wtvrb_9u.json', 'init=/tmp/tmpy5nrbzj0/b99fim6g.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelaqllgtp8/prophet_model-20231030014428.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/opxg_2mp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0wb97v8o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43856', 'data', 'file=/tmp/tmpy5nrbzj0/opxg_2mp.json', 'init=/tmp/tmpy5nrbzj0/0wb97v8o.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model_bfem4yi/prophet_model-20231030014429.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/81yf7z4v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/9lotiobt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54000', 'data', 'file=/tmp/tmpy5nrbzj0/81yf7z4v.json', 'init=/tmp/tmpy5nrbzj0/9lotiobt.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeln14d4axf/prophet_model-20231030014430.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/6tb4cftn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/rran8x6b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74580', 'data', 'file=/tmp/tmpy5nrbzj0/6tb4cftn.json', 'init=/tmp/tmpy5nrbzj0/rran8x6b.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modela2iu3lzt/prophet_model-20231030014431.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/thmd8v22.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/o7hhac4u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51016', 'data', 'file=/tmp/tmpy5nrbzj0/thmd8v22.json', 'init=/tmp/tmpy5nrbzj0/o7hhac4u.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model_pji7ag6/prophet_model-20231030014432.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/6vz8sxdx.json
# 01:44:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/b75juybq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66186', 'data', 'file=/tmp/tmpy5nrbzj0/6vz8sxdx.json', 'init=/tmp/tmpy5nrbzj0/b75juybq.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelxzi1gzlx/prophet_model-20231030014432.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/2r8ug3lz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/af4vi34g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68168', 'data', 'file=/tmp/tmpy5nrbzj0/2r8ug3lz.json', 'init=/tmp/tmpy5nrbzj0/af4vi34g.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelb_5h4v6e/prophet_model-20231030014433.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/k9yxosss.json
# 01:44:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/afvjlwqh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92513', 'data', 'file=/tmp/tmpy5nrbzj0/k9yxosss.json', 'init=/tmp/tmpy5nrbzj0/afvjlwqh.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelc3fd1dhl/prophet_model-20231030014434.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/tfs50i1e.json
# 01:44:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_2ema1l7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14977', 'data', 'file=/tmp/tmpy5nrbzj0/tfs50i1e.json', 'init=/tmp/tmpy5nrbzj0/_2ema1l7.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model3hwgjp4d/prophet_model-20231030014435.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/wkk0z0p2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/jk4p0_nb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81693', 'data', 'file=/tmp/tmpy5nrbzj0/wkk0z0p2.json', 'init=/tmp/tmpy5nrbzj0/jk4p0_nb.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model5t9tdzhx/prophet_model-20231030014436.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:44:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/joc8woby.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/cvozozz0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1047', 'data', 'file=/tmp/tmpy5nrbzj0/joc8woby.json', 'init=/tmp/tmpy5nrbzj0/cvozozz0.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model0hz4modd/prophet_model-20231030014437.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/g95v3fjm.json
# 01:44:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/iee3nn81.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68652', 'data', 'file=/tmp/tmpy5nrbzj0/g95v3fjm.json', 'init=/tmp/tmpy5nrbzj0/iee3nn81.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modela3l10f_a/prophet_model-20231030014437.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_rhedjp_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/d_xcxmec.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94253', 'data', 'file=/tmp/tmpy5nrbzj0/_rhedjp_.json', 'init=/tmp/tmpy5nrbzj0/d_xcxmec.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model1i71_mad/prophet_model-20231030014438.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:44:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:44:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:44:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 0.08031154385204341

# %% [markdown]
# The Mean Absolute Percentage Error (MAPE) from cross-validation is 8.03%, which is slightly better than the baseline model of 8.35%, indicating that we should increase the value of `changepoint_range` from default 80% to 90%.

# %% [markdown]
# ## Step 4.2: Holidays

# %% [markdown]
# Next, let's create two special events: COVID start and Super Bowl.
#
# * For the COVID start event, we set the date to be January 04, 2021, (start of our data) then extend the event to 3 month after using `lower_window` and `upper_window` separately.
#
# * For the Super Bowl event, we set the date in 2021 and 2022 separately, and extend the event to 7 days before and 1 day after.
#
# Then the two events are concatenated together into one dataframe called `events`.

# %%
# COVID time window
COVID = pd.DataFrame({
    'holiday': 'COVID',
    'ds': pd.to_datetime(['2021-01-04']),
    'lower_window': 0,
    'upper_window': 90,
})

# Super Bowl time window
superbowl = pd.DataFrame({
    'holiday': 'superbowl',
    'ds': pd.to_datetime(['2021-02-07','2022-02-13']),
    'lower_window': -7,
    'upper_window': 1,
})

# Combine all events
events = pd.concat((COVID, superbowl))

# Take a look at the events data
events
# Out:
#      holiday         ds  lower_window  upper_window
# 0      COVID 2021-01-04             0            90
# 0  superbowl 2021-02-07            -7             1
# 1  superbowl 2022-02-13            -7             1

# %%
# Add special events
manual_model = Prophet(holidays=events)

# Fit the model on the training dataset
manual_model.fit(data)

# Cross validation
manual_model_cv = cross_validation(manual_model, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")

# Model performance metrics
manual_model_p = performance_metrics(manual_model_cv, rolling_window=1)
manual_model_p['mape'].values[0]
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ttbin2_n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0c8wfcpu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16550', 'data', 'file=/tmp/tmpy5nrbzj0/ttbin2_n.json', 'init=/tmp/tmpy5nrbzj0/0c8wfcpu.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelhhr0v0dd/prophet_model-20231030015011.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:50:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 22 forecasts with cutoffs between 2021-08-09 00:00:00 and 2023-05-01 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x78b81b903490>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/2jjqrmqy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/2e3y0zmf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/n7irqrae.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80756', 'data', 'file=/tmp/tmpy5nrbzj0/2jjqrmqy.json', 'init=/tmp/tmpy5nrbzj0/n7irqrae.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model1ii86a77/prophet_model-20231030015012.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/87dj257n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54526', 'data', 'file=/tmp/tmpy5nrbzj0/2e3y0zmf.json', 'init=/tmp/tmpy5nrbzj0/87dj257n.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelu8q4is_v/prophet_model-20231030015012.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:50:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:50:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/mto2mnba.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/8qs0nu7d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ve0icn56.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14615', 'data', 'file=/tmp/tmpy5nrbzj0/mto2mnba.json', 'init=/tmp/tmpy5nrbzj0/ve0icn56.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model428yim9q/prophet_model-20231030015012.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/k1l3v941.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40043', 'data', 'file=/tmp/tmpy5nrbzj0/8qs0nu7d.json', 'init=/tmp/tmpy5nrbzj0/k1l3v941.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelabh8g759/prophet_model-20231030015012.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:50:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:50:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/4pi3u4p2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/5bsbcd43.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/zchcogqq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9728', 'data', 'file=/tmp/tmpy5nrbzj0/4pi3u4p2.json', 'init=/tmp/tmpy5nrbzj0/zchcogqq.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelx4ep2pl2/prophet_model-20231030015013.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:13 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/95nssdw6.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79824', 'data', 'file=/tmp/tmpy5nrbzj0/5bsbcd43.json', 'init=/tmp/tmpy5nrbzj0/95nssdw6.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model4j1_z0uv/prophet_model-20231030015013.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:50:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:50:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/mcm_zn1h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/53vffyj2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/m3rhmeja.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/yhod20z9.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78363', 'data', 'file=/tmp/tmpy5nrbzj0/mcm_zn1h.json', 'init=/tmp/tmpy5nrbzj0/m3rhmeja.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelmf1vjynz/prophet_model-20231030015014.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:idx 0
# 01:50:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24451', 'data', 'file=/tmp/tmpy5nrbzj0/53vffyj2.json', 'init=/tmp/tmpy5nrbzj0/yhod20z9.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelt5naq33z/prophet_model-20231030015014.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:50:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:50:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/xjwfeqks.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/s9u8wt6p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/j8ez1c36.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20338', 'data', 'file=/tmp/tmpy5nrbzj0/xjwfeqks.json', 'init=/tmp/tmpy5nrbzj0/j8ez1c36.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model44phargb/prophet_model-20231030015014.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_h41v0c4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40854', 'data', 'file=/tmp/tmpy5nrbzj0/s9u8wt6p.json', 'init=/tmp/tmpy5nrbzj0/_h41v0c4.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelc5xxonbn/prophet_model-20231030015014.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:50:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:50:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/4ebpw7h1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/wmy5r0f_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/hhfij8qn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71528', 'data', 'file=/tmp/tmpy5nrbzj0/4ebpw7h1.json', 'init=/tmp/tmpy5nrbzj0/hhfij8qn.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model45yz5pbr/prophet_model-20231030015015.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/w6if4dx7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45619', 'data', 'file=/tmp/tmpy5nrbzj0/wmy5r0f_.json', 'init=/tmp/tmpy5nrbzj0/w6if4dx7.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model7r2_hnnv/prophet_model-20231030015015.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:50:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:50:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/2r5w8bao.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/h3k4cyc9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34724', 'data', 'file=/tmp/tmpy5nrbzj0/2r5w8bao.json', 'init=/tmp/tmpy5nrbzj0/h3k4cyc9.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelpo10439j/prophet_model-20231030015016.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ist5a5lq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/vfz6hnpv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37772', 'data', 'file=/tmp/tmpy5nrbzj0/ist5a5lq.json', 'init=/tmp/tmpy5nrbzj0/vfz6hnpv.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelyxn00g9e/prophet_model-20231030015016.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:50:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:50:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ngs1cz6m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_vx9iuxx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47061', 'data', 'file=/tmp/tmpy5nrbzj0/ngs1cz6m.json', 'init=/tmp/tmpy5nrbzj0/_vx9iuxx.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeltneyu3gz/prophet_model-20231030015017.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:17 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/mnn23yu0.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ijv_59cr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89201', 'data', 'file=/tmp/tmpy5nrbzj0/mnn23yu0.json', 'init=/tmp/tmpy5nrbzj0/ijv_59cr.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelys1gl6pd/prophet_model-20231030015018.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:50:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:50:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/9jmomb36.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0fjw5v17.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/1pkkjl8r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87677', 'data', 'file=/tmp/tmpy5nrbzj0/9jmomb36.json', 'init=/tmp/tmpy5nrbzj0/1pkkjl8r.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model_2pt13kw/prophet_model-20231030015019.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0vzujy2y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8531', 'data', 'file=/tmp/tmpy5nrbzj0/0fjw5v17.json', 'init=/tmp/tmpy5nrbzj0/0vzujy2y.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeli06jdpiy/prophet_model-20231030015019.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:50:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:50:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/me2goqk3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/6gojxcuc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/raxnyasm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89852', 'data', 'file=/tmp/tmpy5nrbzj0/me2goqk3.json', 'init=/tmp/tmpy5nrbzj0/raxnyasm.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelpb6e0swb/prophet_model-20231030015021.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/j2hvy_ia.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30242', 'data', 'file=/tmp/tmpy5nrbzj0/6gojxcuc.json', 'init=/tmp/tmpy5nrbzj0/j2hvy_ia.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelp9_rgvka/prophet_model-20231030015021.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:50:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:50:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/b4d6u34c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/5oavfnry.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/33co6zgm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92039', 'data', 'file=/tmp/tmpy5nrbzj0/b4d6u34c.json', 'init=/tmp/tmpy5nrbzj0/33co6zgm.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeldq0o8k6x/prophet_model-20231030015022.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/kb03clh4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91501', 'data', 'file=/tmp/tmpy5nrbzj0/5oavfnry.json', 'init=/tmp/tmpy5nrbzj0/kb03clh4.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model_4bz6jme/prophet_model-20231030015022.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:50:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:50:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:50:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 0.10854267412709986

# %% [markdown]
# After adding the special events, the Mean Absolute Percentage Error (MAPE) from cross-validation is 10.8%, which is higher than the baseline model of 8.35%, indicating that the special events are not predictive of the stock prices. Therefore, we should not include special events in the model.

# %% [markdown]
# # Step 5: Automatic Hyperparameter Tuning

# %% [markdown]
# There are four hyperparameters that are suitable to be tuned automatically using grid search: `changepoint_prior_scale`, `seasonality_prior_scale`, `holidays_prior_scale`, and `seasonality_mode`.
#
# `holidays_prior_scale` is not applicable because there is no holiday or special events included in the model. We will use grid search to find the best values for the other three hyperparameters.
#
# * Firstly, four values for `changepoint_prior_scale`, five values for `seasonality_prior_scale`, and two values for `seasonality_mode` are used to set up the parameter grid.
# * Then, all combinations of parameters are created and saved in a variable called `all_params`.
# * `mapes` is an empty list created for storing the Mean Absolute Percentage Error (MAPE) for each combination of parameters.
# * After that, we loop through each parameter combination to build a time series model, and save the cross-validation performance results in the list called `mapes`.
# * Finally, we get the best parameters based on the minimum value of Mean Absolute Percentage Error (MAPE), and build a new model using the best parameters.

# %%
# Set up parameter grid
param_grid = {
    'changepoint_prior_scale': [0.001, 0.05, 0.08, 0.5],
    'seasonality_prior_scale': [0.01, 1, 5, 10, 12],
    'seasonality_mode': ['additive', 'multiplicative']
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

# Create a list to store MAPE values for each combination
mapes = []

# Use cross validation to evaluate all parameters
for params in all_params:
    # Fit a model using one parameter combination
    m = Prophet(**params).fit(data)
    # Cross-validation
    df_cv = cross_validation(m, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")
    # Model performance
    df_p = performance_metrics(df_cv, rolling_window=1)
    # Save model performance metrics
    mapes.append(df_p['mape'].values[0])

# Tuning results
tuning_results = pd.DataFrame(all_params)
tuning_results['mape'] = mapes

# Find the best parameters
best_params = all_params[np.argmin(mapes)]
print(best_params)
# Out:
# Streaming output truncated to the last 5000 lines.
# 01:56:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ov90_0pj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/by124600.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72771', 'data', 'file=/tmp/tmpy5nrbzj0/ov90_0pj.json', 'init=/tmp/tmpy5nrbzj0/by124600.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelqgwlzg94/prophet_model-20231030015625.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/o71iv1h3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/hgxezqpw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29147', 'data', 'file=/tmp/tmpy5nrbzj0/o71iv1h3.json', 'init=/tmp/tmpy5nrbzj0/hgxezqpw.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelh_zfccgm/prophet_model-20231030015626.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/tsjyb8_3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/vsz14cy_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5566', 'data', 'file=/tmp/tmpy5nrbzj0/tsjyb8_3.json', 'init=/tmp/tmpy5nrbzj0/vsz14cy_.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model6qxwt4ue/prophet_model-20231030015626.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/lfowyhgv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/nju6y59o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23264', 'data', 'file=/tmp/tmpy5nrbzj0/lfowyhgv.json', 'init=/tmp/tmpy5nrbzj0/nju6y59o.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelvw5_q6b_/prophet_model-20231030015627.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_oc49oyb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/y0kc4p9l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19038', 'data', 'file=/tmp/tmpy5nrbzj0/_oc49oyb.json', 'init=/tmp/tmpy5nrbzj0/y0kc4p9l.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelkjdlc794/prophet_model-20231030015628.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:56:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ju6x02u1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/pf0d9867.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88381', 'data', 'file=/tmp/tmpy5nrbzj0/ju6x02u1.json', 'init=/tmp/tmpy5nrbzj0/pf0d9867.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model5wt8x5je/prophet_model-20231030015628.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/7i1la285.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/w3gmulkc.json
# DEBUG:cmdstanpy:idx 0
# 01:56:28 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69689', 'data', 'file=/tmp/tmpy5nrbzj0/7i1la285.json', 'init=/tmp/tmpy5nrbzj0/w3gmulkc.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model59cmadop/prophet_model-20231030015628.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/a4txvtvo.json
# 01:56:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/7ls0s8g_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16510', 'data', 'file=/tmp/tmpy5nrbzj0/a4txvtvo.json', 'init=/tmp/tmpy5nrbzj0/7ls0s8g_.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model7ju5ucml/prophet_model-20231030015629.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/6e0n7d5o.json
# 01:56:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/bcqf25df.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43630', 'data', 'file=/tmp/tmpy5nrbzj0/6e0n7d5o.json', 'init=/tmp/tmpy5nrbzj0/bcqf25df.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model5wyx695x/prophet_model-20231030015629.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/y018do75.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ozcyyrn_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=458', 'data', 'file=/tmp/tmpy5nrbzj0/y018do75.json', 'init=/tmp/tmpy5nrbzj0/ozcyyrn_.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model86qs8n_y/prophet_model-20231030015630.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 22 forecasts with cutoffs between 2021-08-09 00:00:00 and 2023-05-01 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x78b81b6e1c00>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/kydhczx2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/8ea3ssqr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/4s0fw8pv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/1tpp8a92.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67224', 'data', 'file=/tmp/tmpy5nrbzj0/kydhczx2.json', 'init=/tmp/tmpy5nrbzj0/4s0fw8pv.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modell_e67dmn/prophet_model-20231030015631.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15620', 'data', 'file=/tmp/tmpy5nrbzj0/8ea3ssqr.json', 'init=/tmp/tmpy5nrbzj0/1tpp8a92.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelnsh2wsj1/prophet_model-20231030015631.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:31 - cmdstanpy - INFO - Chain [1] done processing
# 01:56:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/d_bal3sx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/7vqet5p0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92617', 'data', 'file=/tmp/tmpy5nrbzj0/d_bal3sx.json', 'init=/tmp/tmpy5nrbzj0/7vqet5p0.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model0at273o9/prophet_model-20231030015631.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/8_64bj0j.json
# 01:56:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/u804ymci.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62304', 'data', 'file=/tmp/tmpy5nrbzj0/8_64bj0j.json', 'init=/tmp/tmpy5nrbzj0/u804ymci.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelzt5pwm3j/prophet_model-20231030015632.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/m_nufpef.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_rqgnqzh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/7b3uhanf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64349', 'data', 'file=/tmp/tmpy5nrbzj0/m_nufpef.json', 'init=/tmp/tmpy5nrbzj0/_rqgnqzh.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelr9qtnuvh/prophet_model-20231030015632.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/giwqha5m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54627', 'data', 'file=/tmp/tmpy5nrbzj0/7b3uhanf.json', 'init=/tmp/tmpy5nrbzj0/giwqha5m.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeloxui7jyj/prophet_model-20231030015632.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:56:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/z4u3rcp_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/902rdd4l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/i15hcm2t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/dcuxeqku.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70593', 'data', 'file=/tmp/tmpy5nrbzj0/z4u3rcp_.json', 'init=/tmp/tmpy5nrbzj0/i15hcm2t.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modellx73wzu8/prophet_model-20231030015633.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# 01:56:33 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32651', 'data', 'file=/tmp/tmpy5nrbzj0/902rdd4l.json', 'init=/tmp/tmpy5nrbzj0/dcuxeqku.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeljmw_2iue/prophet_model-20231030015633.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:56:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/4pm2ll5m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/wtosshuu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44885', 'data', 'file=/tmp/tmpy5nrbzj0/4pm2ll5m.json', 'init=/tmp/tmpy5nrbzj0/wtosshuu.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelf0zc_ogr/prophet_model-20231030015634.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_106tqhu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/uuf93tn3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52276', 'data', 'file=/tmp/tmpy5nrbzj0/_106tqhu.json', 'init=/tmp/tmpy5nrbzj0/uuf93tn3.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modellb_llia_/prophet_model-20231030015634.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/646i1v7g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/hjsw34w6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2169', 'data', 'file=/tmp/tmpy5nrbzj0/646i1v7g.json', 'init=/tmp/tmpy5nrbzj0/hjsw34w6.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model8kyxtxh6/prophet_model-20231030015634.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/a0twkjci.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/a9h5oyn8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26583', 'data', 'file=/tmp/tmpy5nrbzj0/a0twkjci.json', 'init=/tmp/tmpy5nrbzj0/a9h5oyn8.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeldg0pnrfh/prophet_model-20231030015635.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/c95cga5v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/jihrugje.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76121', 'data', 'file=/tmp/tmpy5nrbzj0/c95cga5v.json', 'init=/tmp/tmpy5nrbzj0/jihrugje.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeltda23qiy/prophet_model-20231030015635.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:56:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/z7pfm5ql.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/izevbrk6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96862', 'data', 'file=/tmp/tmpy5nrbzj0/z7pfm5ql.json', 'init=/tmp/tmpy5nrbzj0/izevbrk6.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeltf_iohgf/prophet_model-20231030015636.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/58xvzbx1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/bayrwxty.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30653', 'data', 'file=/tmp/tmpy5nrbzj0/58xvzbx1.json', 'init=/tmp/tmpy5nrbzj0/bayrwxty.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model8h8ejf_r/prophet_model-20231030015636.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/cb5aat2a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/j9c3levk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65211', 'data', 'file=/tmp/tmpy5nrbzj0/cb5aat2a.json', 'init=/tmp/tmpy5nrbzj0/j9c3levk.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelpo3py3b3/prophet_model-20231030015637.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/vfzmnib5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/z_mo8ib_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59396', 'data', 'file=/tmp/tmpy5nrbzj0/vfzmnib5.json', 'init=/tmp/tmpy5nrbzj0/z_mo8ib_.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modela5pke5q4/prophet_model-20231030015637.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/dp3lko1v.json
# 01:56:38 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0wqxq4jp.json
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61262', 'data', 'file=/tmp/tmpy5nrbzj0/dp3lko1v.json', 'init=/tmp/tmpy5nrbzj0/0wqxq4jp.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelucsb3qr5/prophet_model-20231030015638.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/c7w6z_5r.json
# 01:56:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/q7a9gfk0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81257', 'data', 'file=/tmp/tmpy5nrbzj0/c7w6z_5r.json', 'init=/tmp/tmpy5nrbzj0/q7a9gfk0.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modele5xlheem/prophet_model-20231030015638.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/5wyaal36.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/cwo9ga3j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37121', 'data', 'file=/tmp/tmpy5nrbzj0/5wyaal36.json', 'init=/tmp/tmpy5nrbzj0/cwo9ga3j.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelbe776_oa/prophet_model-20231030015639.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/1i73eg7k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/iqrttjfb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16861', 'data', 'file=/tmp/tmpy5nrbzj0/1i73eg7k.json', 'init=/tmp/tmpy5nrbzj0/iqrttjfb.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelb_ez_q36/prophet_model-20231030015639.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:56:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/p0a8bbfc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ctjaw61q.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4587', 'data', 'file=/tmp/tmpy5nrbzj0/p0a8bbfc.json', 'init=/tmp/tmpy5nrbzj0/ctjaw61q.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model99j53tro/prophet_model-20231030015641.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# 01:56:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/81ib6os7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ay74ieo7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53402', 'data', 'file=/tmp/tmpy5nrbzj0/81ib6os7.json', 'init=/tmp/tmpy5nrbzj0/ay74ieo7.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelmo91qa5s/prophet_model-20231030015641.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 22 forecasts with cutoffs between 2021-08-09 00:00:00 and 2023-05-01 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x78b81b6e0f40>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ec1xz59d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/dqfi39qq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/fgj8bkjd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23898', 'data', 'file=/tmp/tmpy5nrbzj0/ec1xz59d.json', 'init=/tmp/tmpy5nrbzj0/fgj8bkjd.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelm0g21vs3/prophet_model-20231030015642.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/xk65_kcp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18615', 'data', 'file=/tmp/tmpy5nrbzj0/dqfi39qq.json', 'init=/tmp/tmpy5nrbzj0/xk65_kcp.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model5bjq_t7t/prophet_model-20231030015642.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:56:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/2m_q_0fo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_noohq2a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/4gmday1i.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/2feqlu8o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22744', 'data', 'file=/tmp/tmpy5nrbzj0/2m_q_0fo.json', 'init=/tmp/tmpy5nrbzj0/4gmday1i.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model_9r8e9t1/prophet_model-20231030015642.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50751', 'data', 'file=/tmp/tmpy5nrbzj0/_noohq2a.json', 'init=/tmp/tmpy5nrbzj0/2feqlu8o.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model9uj6m4d0/prophet_model-20231030015642.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:42 - cmdstanpy - INFO - Chain [1] start processing
# 01:56:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:56:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/rzf99k3o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/g9xatqex.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/3e_ftjo8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4463', 'data', 'file=/tmp/tmpy5nrbzj0/rzf99k3o.json', 'init=/tmp/tmpy5nrbzj0/3e_ftjo8.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelfguoi81i/prophet_model-20231030015643.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/plltfuis.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97554', 'data', 'file=/tmp/tmpy5nrbzj0/g9xatqex.json', 'init=/tmp/tmpy5nrbzj0/plltfuis.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelu4izolxv/prophet_model-20231030015643.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:56:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/kqvddatg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ki1kejud.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/1gy9zrgn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99705', 'data', 'file=/tmp/tmpy5nrbzj0/kqvddatg.json', 'init=/tmp/tmpy5nrbzj0/1gy9zrgn.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelctcrzylt/prophet_model-20231030015643.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/m46o0zzt.json
# DEBUG:cmdstanpy:idx 0
# 01:56:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# 01:56:43 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# ERROR:cmdstanpy:Chain [1] error: error during processing Operation not permitted
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41230', 'data', 'file=/tmp/tmpy5nrbzj0/ki1kejud.json', 'init=/tmp/tmpy5nrbzj0/m46o0zzt.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelsbprc_5i/prophet_model-20231030015643.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# 01:56:43 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/vr_3tutc.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/3ixy6jgx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2629', 'data', 'file=/tmp/tmpy5nrbzj0/vr_3tutc.json', 'init=/tmp/tmpy5nrbzj0/3ixy6jgx.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeliy19o4n7/prophet_model-20231030015643.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:56:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/f720slp_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/fmegdo46.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37090', 'data', 'file=/tmp/tmpy5nrbzj0/f720slp_.json', 'init=/tmp/tmpy5nrbzj0/fmegdo46.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelssxoye04/prophet_model-20231030015644.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/oye77aip.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/wfeo8iz9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23674', 'data', 'file=/tmp/tmpy5nrbzj0/oye77aip.json', 'init=/tmp/tmpy5nrbzj0/wfeo8iz9.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelvwe3s1xg/prophet_model-20231030015644.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/qjfzcgpx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/fcsxuq0j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7300', 'data', 'file=/tmp/tmpy5nrbzj0/qjfzcgpx.json', 'init=/tmp/tmpy5nrbzj0/fcsxuq0j.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelmc5qr8x8/prophet_model-20231030015645.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/npy3bkuo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/yg48brk3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72097', 'data', 'file=/tmp/tmpy5nrbzj0/npy3bkuo.json', 'init=/tmp/tmpy5nrbzj0/yg48brk3.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model1di2u7sc/prophet_model-20231030015646.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/w9hcv84v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ywuq2d0k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41397', 'data', 'file=/tmp/tmpy5nrbzj0/w9hcv84v.json', 'init=/tmp/tmpy5nrbzj0/ywuq2d0k.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelx5l3v6jo/prophet_model-20231030015647.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/x1ixush9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/wrnnheir.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65183', 'data', 'file=/tmp/tmpy5nrbzj0/x1ixush9.json', 'init=/tmp/tmpy5nrbzj0/wrnnheir.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelrld446yk/prophet_model-20231030015647.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/cmpec3to.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ms4gxinq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26514', 'data', 'file=/tmp/tmpy5nrbzj0/cmpec3to.json', 'init=/tmp/tmpy5nrbzj0/ms4gxinq.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelcfo509de/prophet_model-20231030015648.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/exmwenek.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/cnkg288f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98366', 'data', 'file=/tmp/tmpy5nrbzj0/exmwenek.json', 'init=/tmp/tmpy5nrbzj0/cnkg288f.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelsdl76fyb/prophet_model-20231030015649.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/1c0n63be.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/m2eiz1d3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11975', 'data', 'file=/tmp/tmpy5nrbzj0/1c0n63be.json', 'init=/tmp/tmpy5nrbzj0/m2eiz1d3.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelqb1ie9qq/prophet_model-20231030015650.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ep_rovvu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/mob3oueb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52301', 'data', 'file=/tmp/tmpy5nrbzj0/ep_rovvu.json', 'init=/tmp/tmpy5nrbzj0/mob3oueb.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model_1zoi4v8/prophet_model-20231030015650.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:56:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ll4x0ru_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/z46vy92x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/30h987ih.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9284', 'data', 'file=/tmp/tmpy5nrbzj0/ll4x0ru_.json', 'init=/tmp/tmpy5nrbzj0/30h987ih.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelvs6cm24t/prophet_model-20231030015651.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/thjcvax2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35684', 'data', 'file=/tmp/tmpy5nrbzj0/z46vy92x.json', 'init=/tmp/tmpy5nrbzj0/thjcvax2.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelyejt33_v/prophet_model-20231030015651.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:56:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/yogof7yh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/xf9koon4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/kpvfml3b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69510', 'data', 'file=/tmp/tmpy5nrbzj0/xf9koon4.json', 'init=/tmp/tmpy5nrbzj0/kpvfml3b.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model7zak_mvn/prophet_model-20231030015651.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_eohpdnb.json
# DEBUG:cmdstanpy:idx 0
# 01:56:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99585', 'data', 'file=/tmp/tmpy5nrbzj0/yogof7yh.json', 'init=/tmp/tmpy5nrbzj0/_eohpdnb.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeluzfbdhrg/prophet_model-20231030015651.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:56:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/n4k4kk1v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/yb5lni3m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58691', 'data', 'file=/tmp/tmpy5nrbzj0/n4k4kk1v.json', 'init=/tmp/tmpy5nrbzj0/yb5lni3m.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model2042p3fd/prophet_model-20231030015652.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 22 forecasts with cutoffs between 2021-08-09 00:00:00 and 2023-05-01 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x78b81b6e1b40>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/qhc8zm1j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/bjougcu9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25266', 'data', 'file=/tmp/tmpy5nrbzj0/qhc8zm1j.json', 'init=/tmp/tmpy5nrbzj0/bjougcu9.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelzu04r4me/prophet_model-20231030015653.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/uo6aa6pa.json
# 01:56:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/j7v_p5rn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62404', 'data', 'file=/tmp/tmpy5nrbzj0/uo6aa6pa.json', 'init=/tmp/tmpy5nrbzj0/j7v_p5rn.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelmz1uhvkr/prophet_model-20231030015653.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:53 - cmdstanpy - INFO - Chain [1] start processing
# 01:56:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] done processing
# 01:56:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/w6fghlaj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/f1unwbiu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20292', 'data', 'file=/tmp/tmpy5nrbzj0/w6fghlaj.json', 'init=/tmp/tmpy5nrbzj0/f1unwbiu.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeldn3cvbmp/prophet_model-20231030015654.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/lyu3idon.json
# 01:56:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/gseqtkl7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89830', 'data', 'file=/tmp/tmpy5nrbzj0/lyu3idon.json', 'init=/tmp/tmpy5nrbzj0/gseqtkl7.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelp9l91rgl/prophet_model-20231030015654.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:56:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:56:54 - cmdstanpy - INFO - Chain [1] done processing
# ...
# 02:01:11 - cmdstanpy - INFO - Chain [1] start processing
# 02:01:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/pq4c4274.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_8dimnra.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12950', 'data', 'file=/tmp/tmpy5nrbzj0/pq4c4274.json', 'init=/tmp/tmpy5nrbzj0/_8dimnra.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelbi52m3wm/prophet_model-20231030020112.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/9q4j9_qe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/bch5labv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48750', 'data', 'file=/tmp/tmpy5nrbzj0/9q4j9_qe.json', 'init=/tmp/tmpy5nrbzj0/bch5labv.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelg_lo0tka/prophet_model-20231030020112.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/n_f3iiun.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/tx1h595v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64007', 'data', 'file=/tmp/tmpy5nrbzj0/n_f3iiun.json', 'init=/tmp/tmpy5nrbzj0/tx1h595v.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelna4_k4_f/prophet_model-20231030020113.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/052c9k9r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/04el2chk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57245', 'data', 'file=/tmp/tmpy5nrbzj0/052c9k9r.json', 'init=/tmp/tmpy5nrbzj0/04el2chk.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modell2gwitn7/prophet_model-20231030020113.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/dseacnfk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/cjm5fmgs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93243', 'data', 'file=/tmp/tmpy5nrbzj0/dseacnfk.json', 'init=/tmp/tmpy5nrbzj0/cjm5fmgs.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelrjnxoqqn/prophet_model-20231030020114.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/zp_4wpsm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/zir0vo0p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98605', 'data', 'file=/tmp/tmpy5nrbzj0/zp_4wpsm.json', 'init=/tmp/tmpy5nrbzj0/zir0vo0p.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelk9ecqoki/prophet_model-20231030020115.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/jh5jygvp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/9l_3aymk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57652', 'data', 'file=/tmp/tmpy5nrbzj0/jh5jygvp.json', 'init=/tmp/tmpy5nrbzj0/9l_3aymk.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelh1xj0i20/prophet_model-20231030020115.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/4dn1d8ra.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/g0llyxtp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46984', 'data', 'file=/tmp/tmpy5nrbzj0/4dn1d8ra.json', 'init=/tmp/tmpy5nrbzj0/g0llyxtp.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model415dqt7x/prophet_model-20231030020116.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/i_09klt_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/3zw_cehk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9858', 'data', 'file=/tmp/tmpy5nrbzj0/i_09klt_.json', 'init=/tmp/tmpy5nrbzj0/3zw_cehk.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model_48jfa35/prophet_model-20231030020117.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/b1s4i4bf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/etfp7hqd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41881', 'data', 'file=/tmp/tmpy5nrbzj0/b1s4i4bf.json', 'init=/tmp/tmpy5nrbzj0/etfp7hqd.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model1f54c8or/prophet_model-20231030020118.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:01:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/nr5x4hpp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/rgblq7aa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/kt2riqmd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11146', 'data', 'file=/tmp/tmpy5nrbzj0/nr5x4hpp.json', 'init=/tmp/tmpy5nrbzj0/kt2riqmd.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model77ou_kb2/prophet_model-20231030020119.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/g2zc_lcy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86857', 'data', 'file=/tmp/tmpy5nrbzj0/rgblq7aa.json', 'init=/tmp/tmpy5nrbzj0/g2zc_lcy.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeliw6mfzmd/prophet_model-20231030020119.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/7l69ghi_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/tp2j3ao_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97243', 'data', 'file=/tmp/tmpy5nrbzj0/7l69ghi_.json', 'init=/tmp/tmpy5nrbzj0/tp2j3ao_.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model1p_21yql/prophet_model-20231030020121.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/5vxemrcs.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ppapz40x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53521', 'data', 'file=/tmp/tmpy5nrbzj0/5vxemrcs.json', 'init=/tmp/tmpy5nrbzj0/ppapz40x.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelubtllij2/prophet_model-20231030020122.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/d57q8bib.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/hugt8rmn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49171', 'data', 'file=/tmp/tmpy5nrbzj0/d57q8bib.json', 'init=/tmp/tmpy5nrbzj0/hugt8rmn.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelcjqz6cla/prophet_model-20231030020123.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/2d9xtfm7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/89ti_0fy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40565', 'data', 'file=/tmp/tmpy5nrbzj0/2d9xtfm7.json', 'init=/tmp/tmpy5nrbzj0/89ti_0fy.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelb22kg78j/prophet_model-20231030020123.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/azc664yy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/w4y_0wjg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74124', 'data', 'file=/tmp/tmpy5nrbzj0/azc664yy.json', 'init=/tmp/tmpy5nrbzj0/w4y_0wjg.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelkivrnkna/prophet_model-20231030020124.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/c8l7y3ae.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/bsjzlz7l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8097', 'data', 'file=/tmp/tmpy5nrbzj0/c8l7y3ae.json', 'init=/tmp/tmpy5nrbzj0/bsjzlz7l.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelfkga2aap/prophet_model-20231030020126.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/971h29ci.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ty52st4o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90834', 'data', 'file=/tmp/tmpy5nrbzj0/971h29ci.json', 'init=/tmp/tmpy5nrbzj0/ty52st4o.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelcl30yigk/prophet_model-20231030020126.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/3yx9u_sm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/jcr63rzs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79907', 'data', 'file=/tmp/tmpy5nrbzj0/3yx9u_sm.json', 'init=/tmp/tmpy5nrbzj0/jcr63rzs.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model_h0sl8aa/prophet_model-20231030020128.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:01:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:01:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:01:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# {'changepoint_prior_scale': 0.5, 'seasonality_prior_scale': 0.01, 'seasonality_mode': 'multiplicative'}

# %% [markdown]
# We can see that the best parameters are `changepoint_prior_scale` equals 0.5, `seasonality_prior_scale` equals 0.01, and `seasonality_mode` equals `multiplicative`.

# %%
# Fit the model using the best parameters
auto_model = Prophet(changepoint_prior_scale=best_params['changepoint_prior_scale'],
                     seasonality_prior_scale=best_params['seasonality_prior_scale'],
                     seasonality_mode=best_params['seasonality_mode'])

# Fit the model on the training dataset
auto_model.fit(data)

# Cross validation
auto_model_cv = cross_validation(auto_model, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")

# Model performance metrics
auto_model_p = performance_metrics(auto_model_cv, rolling_window=1)
auto_model_p['mape'].values[0]
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/y5ely672.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/pfcvokhx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70609', 'data', 'file=/tmp/tmpy5nrbzj0/y5ely672.json', 'init=/tmp/tmpy5nrbzj0/pfcvokhx.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelr_t2y9xn/prophet_model-20231030020317.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:03:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 22 forecasts with cutoffs between 2021-08-09 00:00:00 and 2023-05-01 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x78b81b93bf40>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0q0jeswt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/d56x2lzo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/vm4nu3bz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0cqdzs02.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31329', 'data', 'file=/tmp/tmpy5nrbzj0/0q0jeswt.json', 'init=/tmp/tmpy5nrbzj0/vm4nu3bz.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelud_2wb4e/prophet_model-20231030020318.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:18 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57841', 'data', 'file=/tmp/tmpy5nrbzj0/d56x2lzo.json', 'init=/tmp/tmpy5nrbzj0/0cqdzs02.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelr4qznhve/prophet_model-20231030020318.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:03:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:03:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/j4d8ec2k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/qdh1i7gf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95040', 'data', 'file=/tmp/tmpy5nrbzj0/j4d8ec2k.json', 'init=/tmp/tmpy5nrbzj0/qdh1i7gf.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modellyu54ui2/prophet_model-20231030020319.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/bmyhrs7x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/c1ohqq0s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72030', 'data', 'file=/tmp/tmpy5nrbzj0/bmyhrs7x.json', 'init=/tmp/tmpy5nrbzj0/c1ohqq0s.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model582m57rm/prophet_model-20231030020319.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:03:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:03:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/l2uvsoev.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ne1l69_0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65561', 'data', 'file=/tmp/tmpy5nrbzj0/l2uvsoev.json', 'init=/tmp/tmpy5nrbzj0/ne1l69_0.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model3tnvbo0_/prophet_model-20231030020320.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/r0_u82d7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ebcnkvbl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7561', 'data', 'file=/tmp/tmpy5nrbzj0/r0_u82d7.json', 'init=/tmp/tmpy5nrbzj0/ebcnkvbl.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelwkbjbjsv/prophet_model-20231030020320.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:03:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:03:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/wnio9mo2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/zbkc5gyg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/fmq9ulg0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/rhen71tz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50025', 'data', 'file=/tmp/tmpy5nrbzj0/zbkc5gyg.json', 'init=/tmp/tmpy5nrbzj0/fmq9ulg0.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modellj45bkhe/prophet_model-20231030020321.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39884', 'data', 'file=/tmp/tmpy5nrbzj0/wnio9mo2.json', 'init=/tmp/tmpy5nrbzj0/rhen71tz.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model_767hoph/prophet_model-20231030020321.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:21 - cmdstanpy - INFO - Chain [1] start processing
# 02:03:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:03:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:03:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/k4bn_pq1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/5l4d9hvf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/o92x05t7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18500', 'data', 'file=/tmp/tmpy5nrbzj0/k4bn_pq1.json', 'init=/tmp/tmpy5nrbzj0/o92x05t7.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelalcqrnk3/prophet_model-20231030020321.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/pjepnlua.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92385', 'data', 'file=/tmp/tmpy5nrbzj0/5l4d9hvf.json', 'init=/tmp/tmpy5nrbzj0/pjepnlua.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelsfzrnf8j/prophet_model-20231030020321.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:03:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/84ht56aw.json
# 02:03:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/o8e_f8sz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95819', 'data', 'file=/tmp/tmpy5nrbzj0/84ht56aw.json', 'init=/tmp/tmpy5nrbzj0/o8e_f8sz.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model3daq6rpp/prophet_model-20231030020322.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ycor5a3u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/jdmji0pt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83689', 'data', 'file=/tmp/tmpy5nrbzj0/ycor5a3u.json', 'init=/tmp/tmpy5nrbzj0/jdmji0pt.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modell4xh7qp6/prophet_model-20231030020322.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:03:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ee7z725z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/gkncpws1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79791', 'data', 'file=/tmp/tmpy5nrbzj0/ee7z725z.json', 'init=/tmp/tmpy5nrbzj0/gkncpws1.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelzwgefp0f/prophet_model-20231030020322.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:22 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:03:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/wva35x3a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0k6ifwu3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55939', 'data', 'file=/tmp/tmpy5nrbzj0/wva35x3a.json', 'init=/tmp/tmpy5nrbzj0/0k6ifwu3.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model0930080_/prophet_model-20231030020323.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:03:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/28t4sjho.json
# 02:03:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/87dxi477.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76105', 'data', 'file=/tmp/tmpy5nrbzj0/28t4sjho.json', 'init=/tmp/tmpy5nrbzj0/87dxi477.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelsfry5hoa/prophet_model-20231030020323.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/hb70nw1q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ff_2cuxi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75575', 'data', 'file=/tmp/tmpy5nrbzj0/hb70nw1q.json', 'init=/tmp/tmpy5nrbzj0/ff_2cuxi.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model5bjmpuom/prophet_model-20231030020323.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:03:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:03:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/xb54op2y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/x49gjsxk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56325', 'data', 'file=/tmp/tmpy5nrbzj0/xb54op2y.json', 'init=/tmp/tmpy5nrbzj0/x49gjsxk.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model6z55qt_2/prophet_model-20231030020324.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/5j7qsg7g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_ezo3o5m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46705', 'data', 'file=/tmp/tmpy5nrbzj0/5j7qsg7g.json', 'init=/tmp/tmpy5nrbzj0/_ezo3o5m.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model1necnbuo/prophet_model-20231030020324.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:03:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:03:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/m0tl8bna.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/hynatfd_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52533', 'data', 'file=/tmp/tmpy5nrbzj0/m0tl8bna.json', 'init=/tmp/tmpy5nrbzj0/hynatfd_.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modely32tkqlt/prophet_model-20231030020325.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/l2f0o8cf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/4soxvow2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6208', 'data', 'file=/tmp/tmpy5nrbzj0/l2f0o8cf.json', 'init=/tmp/tmpy5nrbzj0/4soxvow2.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model6hy9cos1/prophet_model-20231030020325.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:03:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:03:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/fq5l09en.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/erysbnre.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97834', 'data', 'file=/tmp/tmpy5nrbzj0/fq5l09en.json', 'init=/tmp/tmpy5nrbzj0/erysbnre.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelgfbkimme/prophet_model-20231030020327.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/9sbucejl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/2kq3t0_x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33963', 'data', 'file=/tmp/tmpy5nrbzj0/9sbucejl.json', 'init=/tmp/tmpy5nrbzj0/2kq3t0_x.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelnjfzd3ge/prophet_model-20231030020327.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:03:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:03:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:03:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 0.057231920661833

# %% [markdown]
# The Mean Absolute Percentage Error (MAPE) from cross-validation is 5.72% for the model with the best parameters, which is better than the baseline model of 8.35%.

# %% [markdown]
# # Step 6: Automatic Hyperparameter Tuning using Log Data

# %% [markdown]
# The prophet model documentation[2] mentioned some hyperparameters are best tuned in log scale. In step 6, we will transform the data to the log form, and then do the automatic hyperparameter tuning.

# %% [markdown]
# * Firstly, a copy of the modeling data is created with the name `data_log`
# * Then, the log scale data is created by taking the natural log of the stock prices.
# * After that, the original stock prices are deleted and the log scale stock prices are renamed to `y`.
# * Lastly, the new log-scale data is used for grid search, and the best parameters are used for the final model.

# %%
# Create a copy of the data
data_log = data.copy()

# Create the log scale data by taking the natual log of the stock prices.
data_log['y_log'] = np.log(data['y'])

# Delete the stock price and rename the log scale stock price to y
data_log = data_log.drop('y', axis=1).rename(columns={'y_log': 'y'})

# Take a look at the data
data_log.head()
# Out:
#           ds         y
# 0 2021-01-04  4.459127
# 1 2021-01-05  4.466437
# 2 2021-01-06  4.463198
# 3 2021-01-07  4.492701
# 4 2021-01-08  4.503807

# %%
# Parameter grid
param_grid = {
    'changepoint_prior_scale': [0.001, 0.05, 0.08, 0.5],
    'seasonality_prior_scale': [0.01, 1.0, 5, 10, 12],
    'seasonality_mode': ['additive', 'multiplicative']
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
mapes = []  # Store the MAPEs for each params here

# Use cross validation to evaluate all parameters
for params in all_params:
    # Fit a model using one parameter combination
    m = Prophet(**params).fit(data_log)
    # Cross-validation
    df_cv = cross_validation(m, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")
    # Model performance
    df_p = performance_metrics(df_cv, rolling_window=1)
    # Save model performance metrics
    mapes.append(df_p['mape'].values[0])

# Tuning results
best_params = all_params[np.argmin(mapes)]

# Best parameters
print(best_params)
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/fruh43gd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/rnu_4skr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/df2_77po.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/077l8wdg.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=265', 'data', 'file=/tmp/tmpy5nrbzj0/fruh43gd.json', 'init=/tmp/tmpy5nrbzj0/df2_77po.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelprs3lerq/prophet_model-20231030020804.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:04 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88052', 'data', 'file=/tmp/tmpy5nrbzj0/rnu_4skr.json', 'init=/tmp/tmpy5nrbzj0/077l8wdg.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model7za7ccf8/prophet_model-20231030020804.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/svlgus8g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/imnqr7el.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17910', 'data', 'file=/tmp/tmpy5nrbzj0/svlgus8g.json', 'init=/tmp/tmpy5nrbzj0/imnqr7el.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model2o8u599c/prophet_model-20231030020805.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/wsblgph6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/xwwnd_1m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67255', 'data', 'file=/tmp/tmpy5nrbzj0/wsblgph6.json', 'init=/tmp/tmpy5nrbzj0/xwwnd_1m.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model7sk4fb6h/prophet_model-20231030020805.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/o97e77fs.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/5closj_2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16643', 'data', 'file=/tmp/tmpy5nrbzj0/o97e77fs.json', 'init=/tmp/tmpy5nrbzj0/5closj_2.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model4w3zoge4/prophet_model-20231030020805.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/nyj9djvb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/i5crtc0b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78201', 'data', 'file=/tmp/tmpy5nrbzj0/nyj9djvb.json', 'init=/tmp/tmpy5nrbzj0/i5crtc0b.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model9695fs7q/prophet_model-20231030020805.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/gbrjc5k6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/seeefghe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10203', 'data', 'file=/tmp/tmpy5nrbzj0/gbrjc5k6.json', 'init=/tmp/tmpy5nrbzj0/seeefghe.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_models055__8n/prophet_model-20231030020806.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/jr2kpqq_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/9zyevc6u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27718', 'data', 'file=/tmp/tmpy5nrbzj0/jr2kpqq_.json', 'init=/tmp/tmpy5nrbzj0/9zyevc6u.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelb2jiwm_x/prophet_model-20231030020806.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:06 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/73wwxav5.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/1akrql5o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26708', 'data', 'file=/tmp/tmpy5nrbzj0/73wwxav5.json', 'init=/tmp/tmpy5nrbzj0/1akrql5o.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model8j_gwj8l/prophet_model-20231030020806.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/3y0t_t8j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_djasjax.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37736', 'data', 'file=/tmp/tmpy5nrbzj0/3y0t_t8j.json', 'init=/tmp/tmpy5nrbzj0/_djasjax.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model32c0irse/prophet_model-20231030020807.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/qte6tmm4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/81boosu6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51851', 'data', 'file=/tmp/tmpy5nrbzj0/qte6tmm4.json', 'init=/tmp/tmpy5nrbzj0/81boosu6.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelk1e3hza4/prophet_model-20231030020807.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/vistb52d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/u92wo4lx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87524', 'data', 'file=/tmp/tmpy5nrbzj0/vistb52d.json', 'init=/tmp/tmpy5nrbzj0/u92wo4lx.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelf8p324vm/prophet_model-20231030020808.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/x78fh9nm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/w94qymm0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85452', 'data', 'file=/tmp/tmpy5nrbzj0/x78fh9nm.json', 'init=/tmp/tmpy5nrbzj0/w94qymm0.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeldi_howh7/prophet_model-20231030020808.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/3wzez2ew.json
# 02:08:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/7myrfs4a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24746', 'data', 'file=/tmp/tmpy5nrbzj0/3wzez2ew.json', 'init=/tmp/tmpy5nrbzj0/7myrfs4a.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model_413u5r8/prophet_model-20231030020809.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/df_4pv_n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/o722p5xr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51546', 'data', 'file=/tmp/tmpy5nrbzj0/df_4pv_n.json', 'init=/tmp/tmpy5nrbzj0/o722p5xr.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeli0axqqk4/prophet_model-20231030020809.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_nmv2rqr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/rey9ka_1.json
# DEBUG:cmdstanpy:idx 0
# 02:08:09 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70809', 'data', 'file=/tmp/tmpy5nrbzj0/_nmv2rqr.json', 'init=/tmp/tmpy5nrbzj0/rey9ka_1.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeluaz56izb/prophet_model-20231030020809.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ia7q_2ih.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/lvr4dwgu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38738', 'data', 'file=/tmp/tmpy5nrbzj0/ia7q_2ih.json', 'init=/tmp/tmpy5nrbzj0/lvr4dwgu.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model47u4b7fk/prophet_model-20231030020810.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 22 forecasts with cutoffs between 2021-08-09 00:00:00 and 2023-05-01 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x78b81b49f280>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/mxq5imdk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/3j_bd09r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59222', 'data', 'file=/tmp/tmpy5nrbzj0/mxq5imdk.json', 'init=/tmp/tmpy5nrbzj0/3j_bd09r.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelxb9_ld7f/prophet_model-20231030020813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:13 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/iao18siy.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/bsch0t47.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11527', 'data', 'file=/tmp/tmpy5nrbzj0/iao18siy.json', 'init=/tmp/tmpy5nrbzj0/bsch0t47.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelpi1yf7b1/prophet_model-20231030020813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/tycq0phu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/hmo1pjqt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1705', 'data', 'file=/tmp/tmpy5nrbzj0/tycq0phu.json', 'init=/tmp/tmpy5nrbzj0/hmo1pjqt.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modellyy618xh/prophet_model-20231030020813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ucjyifzh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/gwhsyhjn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70406', 'data', 'file=/tmp/tmpy5nrbzj0/ucjyifzh.json', 'init=/tmp/tmpy5nrbzj0/gwhsyhjn.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model2km7x4bj/prophet_model-20231030020813.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:13 - cmdstanpy - INFO - Chain [1] done processing
# 02:08:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/c8j7drrm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0gh981mw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89051', 'data', 'file=/tmp/tmpy5nrbzj0/c8j7drrm.json', 'init=/tmp/tmpy5nrbzj0/0gh981mw.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model65zvkdak/prophet_model-20231030020814.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/12jd_bgw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/sj9okpx9.json
# 02:08:14 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:idx 0
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19997', 'data', 'file=/tmp/tmpy5nrbzj0/12jd_bgw.json', 'init=/tmp/tmpy5nrbzj0/sj9okpx9.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model9q1va99j/prophet_model-20231030020814.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0ya51uu3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/qrtm9yab.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41318', 'data', 'file=/tmp/tmpy5nrbzj0/0ya51uu3.json', 'init=/tmp/tmpy5nrbzj0/qrtm9yab.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelt1y079jl/prophet_model-20231030020814.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/q6nphqyr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/rnwvyukc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51452', 'data', 'file=/tmp/tmpy5nrbzj0/q6nphqyr.json', 'init=/tmp/tmpy5nrbzj0/rnwvyukc.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelkjd7hyr7/prophet_model-20231030020814.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:15 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/tfaep6hq.json
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/2e7tmxcz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12771', 'data', 'file=/tmp/tmpy5nrbzj0/tfaep6hq.json', 'init=/tmp/tmpy5nrbzj0/2e7tmxcz.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelnk517ale/prophet_model-20231030020815.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/bmrkph45.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/el4yklpn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79507', 'data', 'file=/tmp/tmpy5nrbzj0/bmrkph45.json', 'init=/tmp/tmpy5nrbzj0/el4yklpn.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelmvy6h5hk/prophet_model-20231030020815.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/5qt0t38y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/yukzbpz8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60738', 'data', 'file=/tmp/tmpy5nrbzj0/5qt0t38y.json', 'init=/tmp/tmpy5nrbzj0/yukzbpz8.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeleyebkk8w/prophet_model-20231030020815.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0cjnz4mp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/g8h7ie41.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/b_dr_cpv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90122', 'data', 'file=/tmp/tmpy5nrbzj0/0cjnz4mp.json', 'init=/tmp/tmpy5nrbzj0/b_dr_cpv.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelzp8b4w25/prophet_model-20231030020817.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/dxdusjap.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63748', 'data', 'file=/tmp/tmpy5nrbzj0/g8h7ie41.json', 'init=/tmp/tmpy5nrbzj0/dxdusjap.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelwbwwjwjc/prophet_model-20231030020817.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/d3dkkkug.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/52oeses7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79252', 'data', 'file=/tmp/tmpy5nrbzj0/d3dkkkug.json', 'init=/tmp/tmpy5nrbzj0/52oeses7.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model67idwuri/prophet_model-20231030020818.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ui6ys40x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/8amrndhs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9577', 'data', 'file=/tmp/tmpy5nrbzj0/ui6ys40x.json', 'init=/tmp/tmpy5nrbzj0/8amrndhs.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeljr3wpw86/prophet_model-20231030020818.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/h4hw7veb.json
# 02:08:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/rs_bo7f7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58724', 'data', 'file=/tmp/tmpy5nrbzj0/h4hw7veb.json', 'init=/tmp/tmpy5nrbzj0/rs_bo7f7.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelcd9yv1xh/prophet_model-20231030020819.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/1gop0kmy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/mm09jjyb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88092', 'data', 'file=/tmp/tmpy5nrbzj0/1gop0kmy.json', 'init=/tmp/tmpy5nrbzj0/mm09jjyb.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelw0hj0n12/prophet_model-20231030020820.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/z63_sslx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/s4sfzzgu.json
# DEBUG:cmdstanpy:idx 0
# 02:08:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75650', 'data', 'file=/tmp/tmpy5nrbzj0/z63_sslx.json', 'init=/tmp/tmpy5nrbzj0/s4sfzzgu.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelwyhii3hz/prophet_model-20231030020821.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/u2s_8dg5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/zahwt078.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25826', 'data', 'file=/tmp/tmpy5nrbzj0/u2s_8dg5.json', 'init=/tmp/tmpy5nrbzj0/zahwt078.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeluj6xo8n_/prophet_model-20231030020821.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/tr1gvt6y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/w30mj8k8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44', 'data', 'file=/tmp/tmpy5nrbzj0/tr1gvt6y.json', 'init=/tmp/tmpy5nrbzj0/w30mj8k8.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeltw3qwqob/prophet_model-20231030020823.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ohr8bwv0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/h9o8171w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22643', 'data', 'file=/tmp/tmpy5nrbzj0/ohr8bwv0.json', 'init=/tmp/tmpy5nrbzj0/h9o8171w.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model25fpzqa0/prophet_model-20231030020824.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/zb10vlq0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/lga33l3k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52455', 'data', 'file=/tmp/tmpy5nrbzj0/zb10vlq0.json', 'init=/tmp/tmpy5nrbzj0/lga33l3k.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeloy8w4kvz/prophet_model-20231030020825.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/mwac5p1e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ru8864xh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48743', 'data', 'file=/tmp/tmpy5nrbzj0/mwac5p1e.json', 'init=/tmp/tmpy5nrbzj0/ru8864xh.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelegft2uhl/prophet_model-20231030020828.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 22 forecasts with cutoffs between 2021-08-09 00:00:00 and 2023-05-01 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x78b81b49de10>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/h0q_qos1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/slidsp5t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/2rz8a76o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/o2icnl95.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93495', 'data', 'file=/tmp/tmpy5nrbzj0/h0q_qos1.json', 'init=/tmp/tmpy5nrbzj0/2rz8a76o.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelzl1giv6f/prophet_model-20231030020828.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:idx 0
# 02:08:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44387', 'data', 'file=/tmp/tmpy5nrbzj0/slidsp5t.json', 'init=/tmp/tmpy5nrbzj0/o2icnl95.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelfpxpfw68/prophet_model-20231030020828.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/op8vdt5p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/1jbd0cuh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/7j9n1hir.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/n6mn1c2o.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98018', 'data', 'file=/tmp/tmpy5nrbzj0/op8vdt5p.json', 'init=/tmp/tmpy5nrbzj0/7j9n1hir.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelz81_timx/prophet_model-20231030020829.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47859', 'data', 'file=/tmp/tmpy5nrbzj0/1jbd0cuh.json', 'init=/tmp/tmpy5nrbzj0/n6mn1c2o.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelrnnu4br_/prophet_model-20231030020829.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:29 - cmdstanpy - INFO - Chain [1] done processing
# 02:08:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/9y9y7b12.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/d_x01o_g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16489', 'data', 'file=/tmp/tmpy5nrbzj0/9y9y7b12.json', 'init=/tmp/tmpy5nrbzj0/d_x01o_g.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelypset3lr/prophet_model-20231030020829.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:29 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/xz6nmvi6.json
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/vz46zyit.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40715', 'data', 'file=/tmp/tmpy5nrbzj0/xz6nmvi6.json', 'init=/tmp/tmpy5nrbzj0/vz46zyit.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model1nk2vonf/prophet_model-20231030020829.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/9hoo7ydi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ixec5q25.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82662', 'data', 'file=/tmp/tmpy5nrbzj0/9hoo7ydi.json', 'init=/tmp/tmpy5nrbzj0/ixec5q25.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelg3fhrr7b/prophet_model-20231030020830.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/jnu5hmqo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/jqqcuhd2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1317', 'data', 'file=/tmp/tmpy5nrbzj0/jnu5hmqo.json', 'init=/tmp/tmpy5nrbzj0/jqqcuhd2.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelzk8xqxm7/prophet_model-20231030020830.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/pe07e475.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/15hobktr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16544', 'data', 'file=/tmp/tmpy5nrbzj0/pe07e475.json', 'init=/tmp/tmpy5nrbzj0/15hobktr.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model7c4lwmlp/prophet_model-20231030020830.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/kq0az6dg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/1tempth7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52978', 'data', 'file=/tmp/tmpy5nrbzj0/kq0az6dg.json', 'init=/tmp/tmpy5nrbzj0/1tempth7.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model76zdygxh/prophet_model-20231030020830.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/xcx1yxwt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/rbui2gbo.json
# 02:08:31 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:idx 0
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97164', 'data', 'file=/tmp/tmpy5nrbzj0/xcx1yxwt.json', 'init=/tmp/tmpy5nrbzj0/rbui2gbo.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model0zmnk_5o/prophet_model-20231030020831.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/j_jycptb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/uixafkwq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63915', 'data', 'file=/tmp/tmpy5nrbzj0/j_jycptb.json', 'init=/tmp/tmpy5nrbzj0/uixafkwq.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelfz7pz8lr/prophet_model-20231030020831.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/yhp_ylje.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/im01jpl1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44889', 'data', 'file=/tmp/tmpy5nrbzj0/yhp_ylje.json', 'init=/tmp/tmpy5nrbzj0/im01jpl1.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model5y69m97e/prophet_model-20231030020832.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/oph5kq2v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0xy7_grx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32798', 'data', 'file=/tmp/tmpy5nrbzj0/oph5kq2v.json', 'init=/tmp/tmpy5nrbzj0/0xy7_grx.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeljjqx2b6g/prophet_model-20231030020832.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/42hu2pxm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/j9opm9s3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34591', 'data', 'file=/tmp/tmpy5nrbzj0/42hu2pxm.json', 'init=/tmp/tmpy5nrbzj0/j9opm9s3.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelv0h7moka/prophet_model-20231030020832.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/hr3c1uj7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ai_x3i_m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69522', 'data', 'file=/tmp/tmpy5nrbzj0/hr3c1uj7.json', 'init=/tmp/tmpy5nrbzj0/ai_x3i_m.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelwq9xissi/prophet_model-20231030020833.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/rd4yqq83.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/3mztnjbm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48779', 'data', 'file=/tmp/tmpy5nrbzj0/rd4yqq83.json', 'init=/tmp/tmpy5nrbzj0/3mztnjbm.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelfyl9jlm6/prophet_model-20231030020833.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:08:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/jrgkcofv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/233jlst8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ldy095ci.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44662', 'data', 'file=/tmp/tmpy5nrbzj0/jrgkcofv.json', 'init=/tmp/tmpy5nrbzj0/ldy095ci.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model0nhccx21/prophet_model-20231030020834.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/0nwp6mcm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90284', 'data', 'file=/tmp/tmpy5nrbzj0/233jlst8.json', 'init=/tmp/tmpy5nrbzj0/0nwp6mcm.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model3f6shtt1/prophet_model-20231030020834.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/x6dhlss3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/99fykf3c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65515', 'data', 'file=/tmp/tmpy5nrbzj0/x6dhlss3.json', 'init=/tmp/tmpy5nrbzj0/99fykf3c.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelo8zl4bpb/prophet_model-20231030020835.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/2qkh73n7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ic3i0shd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37313', 'data', 'file=/tmp/tmpy5nrbzj0/2qkh73n7.json', 'init=/tmp/tmpy5nrbzj0/ic3i0shd.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelxthrh9nk/prophet_model-20231030020835.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/6whajf41.json
# 02:08:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/2qeuutd1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85846', 'data', 'file=/tmp/tmpy5nrbzj0/6whajf41.json', 'init=/tmp/tmpy5nrbzj0/2qeuutd1.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model1o8wiq_a/prophet_model-20231030020836.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:08:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:08:36 - cmdstanpy - INFO - Chain [1] done processing
# ...
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12646', 'data', 'file=/tmp/tmpy5nrbzj0/hxldusp0.json', 'init=/tmp/tmpy5nrbzj0/u4247ox_.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelwiuehdkx/prophet_model-20231030021252.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:12:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:12:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:12:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/6d9jvurk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/cjg0tnjb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22589', 'data', 'file=/tmp/tmpy5nrbzj0/6d9jvurk.json', 'init=/tmp/tmpy5nrbzj0/cjg0tnjb.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelcbpaf0y4/prophet_model-20231030021253.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:12:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/uaubvq7m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/1hnwgpqu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49600', 'data', 'file=/tmp/tmpy5nrbzj0/uaubvq7m.json', 'init=/tmp/tmpy5nrbzj0/1hnwgpqu.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelwued3xc6/prophet_model-20231030021254.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:12:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:12:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:12:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/synojq97.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ar9mluzd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64866', 'data', 'file=/tmp/tmpy5nrbzj0/synojq97.json', 'init=/tmp/tmpy5nrbzj0/ar9mluzd.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelsi783hff/prophet_model-20231030021255.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:12:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/wprrrtu_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/myzmxn1v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96450', 'data', 'file=/tmp/tmpy5nrbzj0/wprrrtu_.json', 'init=/tmp/tmpy5nrbzj0/myzmxn1v.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeljwjw0om4/prophet_model-20231030021255.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:12:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:12:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:12:56 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/jmxz7zjk.json
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/c908st38.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48935', 'data', 'file=/tmp/tmpy5nrbzj0/jmxz7zjk.json', 'init=/tmp/tmpy5nrbzj0/c908st38.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model4ng6bvjv/prophet_model-20231030021256.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:12:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/t0vefv2z.json
# 02:12:56 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ewuzldi8.json
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85776', 'data', 'file=/tmp/tmpy5nrbzj0/t0vefv2z.json', 'init=/tmp/tmpy5nrbzj0/ewuzldi8.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelwq2k0usb/prophet_model-20231030021256.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:12:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:12:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/23608_as.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/yvok9yw7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98154', 'data', 'file=/tmp/tmpy5nrbzj0/23608_as.json', 'init=/tmp/tmpy5nrbzj0/yvok9yw7.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model0khgt2c2/prophet_model-20231030021257.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:12:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/4en0tuah.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/fqkl1ta3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24725', 'data', 'file=/tmp/tmpy5nrbzj0/4en0tuah.json', 'init=/tmp/tmpy5nrbzj0/fqkl1ta3.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelvm8msw0d/prophet_model-20231030021257.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:12:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:12:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ilci4czo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/apnjq6qc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3426', 'data', 'file=/tmp/tmpy5nrbzj0/ilci4czo.json', 'init=/tmp/tmpy5nrbzj0/apnjq6qc.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeld_ymj8f1/prophet_model-20231030021257.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:12:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:12:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/5v29mb_w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/edup778o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3195', 'data', 'file=/tmp/tmpy5nrbzj0/5v29mb_w.json', 'init=/tmp/tmpy5nrbzj0/edup778o.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelfifbbq6l/prophet_model-20231030021258.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:12:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:12:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/q8e2zhzk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/emtf22xn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87497', 'data', 'file=/tmp/tmpy5nrbzj0/q8e2zhzk.json', 'init=/tmp/tmpy5nrbzj0/emtf22xn.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeltdmn2mna/prophet_model-20231030021259.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:12:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:12:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/3nn9tp2w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ihlkk6bq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28585', 'data', 'file=/tmp/tmpy5nrbzj0/3nn9tp2w.json', 'init=/tmp/tmpy5nrbzj0/ihlkk6bq.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelh689ki6h/prophet_model-20231030021259.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:12:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:13:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:13:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/oa7ps_xn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/xnd6qgqy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12424', 'data', 'file=/tmp/tmpy5nrbzj0/oa7ps_xn.json', 'init=/tmp/tmpy5nrbzj0/xnd6qgqy.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelmj9zg70c/prophet_model-20231030021300.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:13:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/81x6jmt9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/nrqtaw7m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83873', 'data', 'file=/tmp/tmpy5nrbzj0/81x6jmt9.json', 'init=/tmp/tmpy5nrbzj0/nrqtaw7m.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelgwr_b0pq/prophet_model-20231030021300.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:13:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:13:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/tu36po2_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/j4wnti_v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74866', 'data', 'file=/tmp/tmpy5nrbzj0/tu36po2_.json', 'init=/tmp/tmpy5nrbzj0/j4wnti_v.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelwbg4oaw7/prophet_model-20231030021301.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:13:01 - cmdstanpy - INFO - Chain [1] start processing
# 02:13:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ex7ufo63.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/t6l9inke.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28624', 'data', 'file=/tmp/tmpy5nrbzj0/ex7ufo63.json', 'init=/tmp/tmpy5nrbzj0/t6l9inke.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelnpv9hnhd/prophet_model-20231030021302.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:13:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:13:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_ny346mr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/r9w4gom9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31782', 'data', 'file=/tmp/tmpy5nrbzj0/_ny346mr.json', 'init=/tmp/tmpy5nrbzj0/r9w4gom9.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelfwecyqo3/prophet_model-20231030021303.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:13:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:13:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/2da2dtuo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/63nfztu0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27308', 'data', 'file=/tmp/tmpy5nrbzj0/2da2dtuo.json', 'init=/tmp/tmpy5nrbzj0/63nfztu0.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelyd6mrqa7/prophet_model-20231030021303.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:13:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:13:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/vt8tkz4p.json
# 02:13:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/w7lk356c.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85405', 'data', 'file=/tmp/tmpy5nrbzj0/vt8tkz4p.json', 'init=/tmp/tmpy5nrbzj0/w7lk356c.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_models3lzf39u/prophet_model-20231030021304.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:13:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/d7qzi3p3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/zy27ejvt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11563', 'data', 'file=/tmp/tmpy5nrbzj0/d7qzi3p3.json', 'init=/tmp/tmpy5nrbzj0/zy27ejvt.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelohnjqfof/prophet_model-20231030021305.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:13:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:13:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:13:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# {'changepoint_prior_scale': 0.08, 'seasonality_prior_scale': 0.01, 'seasonality_mode': 'multiplicative'}

# %%
# Train model using best parameters
auto_model_log = Prophet(changepoint_prior_scale=best_params['changepoint_prior_scale'],
                     seasonality_prior_scale=best_params['seasonality_prior_scale'],
                     seasonality_mode=best_params['seasonality_mode'])

# Fit the model on the training dataset
auto_model_log.fit(data_log)

# Cross validation
auto_model_log_cv = cross_validation(auto_model_log, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")

# Model performance metrics
auto_model_log_p = performance_metrics(auto_model_log_cv, rolling_window=1)
auto_model_log_p['mape'].values[0]
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/9jgddvpz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/yyvh7u87.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29164', 'data', 'file=/tmp/tmpy5nrbzj0/9jgddvpz.json', 'init=/tmp/tmpy5nrbzj0/yyvh7u87.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model6dvqgl94/prophet_model-20231030022154.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:21:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 22 forecasts with cutoffs between 2021-08-09 00:00:00 and 2023-05-01 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x78b85ac22ec0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/zyghrn85.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/h7fs7ax6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/9x1s00af.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88317', 'data', 'file=/tmp/tmpy5nrbzj0/zyghrn85.json', 'init=/tmp/tmpy5nrbzj0/9x1s00af.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model8aauwwtp/prophet_model-20231030022155.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:55 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/y544n551.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34510', 'data', 'file=/tmp/tmpy5nrbzj0/h7fs7ax6.json', 'init=/tmp/tmpy5nrbzj0/y544n551.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model155t2unu/prophet_model-20231030022155.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:21:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:21:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/zkvo9zec.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/lw6vyr3d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16230', 'data', 'file=/tmp/tmpy5nrbzj0/zkvo9zec.json', 'init=/tmp/tmpy5nrbzj0/lw6vyr3d.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelyf76i99w/prophet_model-20231030022155.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/d5cqmivz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/aybcvfuq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29703', 'data', 'file=/tmp/tmpy5nrbzj0/d5cqmivz.json', 'init=/tmp/tmpy5nrbzj0/aybcvfuq.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelr7lcjxtl/prophet_model-20231030022156.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:21:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:21:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/o8blk9gd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/t62o6zj1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/b00ln1tx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ipqy2bbl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3681', 'data', 'file=/tmp/tmpy5nrbzj0/t62o6zj1.json', 'init=/tmp/tmpy5nrbzj0/b00ln1tx.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model11zmp_3d/prophet_model-20231030022156.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6455', 'data', 'file=/tmp/tmpy5nrbzj0/o8blk9gd.json', 'init=/tmp/tmpy5nrbzj0/ipqy2bbl.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelivxe0oan/prophet_model-20231030022156.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:21:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:21:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/zyb29aqq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/7e_484iu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98416', 'data', 'file=/tmp/tmpy5nrbzj0/zyb29aqq.json', 'init=/tmp/tmpy5nrbzj0/7e_484iu.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelodqiraxc/prophet_model-20231030022157.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/j05lmmeq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/bitc2xxs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42691', 'data', 'file=/tmp/tmpy5nrbzj0/j05lmmeq.json', 'init=/tmp/tmpy5nrbzj0/bitc2xxs.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model8kr7zlo_/prophet_model-20231030022157.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:21:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:21:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/adv8v81_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/eutio3er.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91129', 'data', 'file=/tmp/tmpy5nrbzj0/adv8v81_.json', 'init=/tmp/tmpy5nrbzj0/eutio3er.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeldljc2kg4/prophet_model-20231030022158.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/r2a7m1a6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/muyh6rzk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88658', 'data', 'file=/tmp/tmpy5nrbzj0/r2a7m1a6.json', 'init=/tmp/tmpy5nrbzj0/muyh6rzk.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelffn8l0pl/prophet_model-20231030022158.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:21:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_uu607c1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/uu2atgbw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60763', 'data', 'file=/tmp/tmpy5nrbzj0/_uu607c1.json', 'init=/tmp/tmpy5nrbzj0/uu2atgbw.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modeluvkcqsoc/prophet_model-20231030022159.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:21:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/g4xw6cu0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ho83sor0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84558', 'data', 'file=/tmp/tmpy5nrbzj0/g4xw6cu0.json', 'init=/tmp/tmpy5nrbzj0/ho83sor0.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelyrzwau3t/prophet_model-20231030022159.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:21:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/5mc6o9t9.json
# 02:21:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/frfbiq6y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=303', 'data', 'file=/tmp/tmpy5nrbzj0/5mc6o9t9.json', 'init=/tmp/tmpy5nrbzj0/frfbiq6y.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model7kpih7i6/prophet_model-20231030022159.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:21:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/_qub1va1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/8knvwino.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78823', 'data', 'file=/tmp/tmpy5nrbzj0/_qub1va1.json', 'init=/tmp/tmpy5nrbzj0/8knvwino.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model5qnb1vwd/prophet_model-20231030022200.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:22:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:22:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/seglnd2y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/skhvlj20.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88064', 'data', 'file=/tmp/tmpy5nrbzj0/seglnd2y.json', 'init=/tmp/tmpy5nrbzj0/skhvlj20.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modele3thhdio/prophet_model-20231030022200.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:22:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:22:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/84qy2c0x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/wbc8qhmy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53109', 'data', 'file=/tmp/tmpy5nrbzj0/84qy2c0x.json', 'init=/tmp/tmpy5nrbzj0/wbc8qhmy.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model2vh80jeg/prophet_model-20231030022200.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:22:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:22:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:22:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/5finshz2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/ihdkfv5p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74869', 'data', 'file=/tmp/tmpy5nrbzj0/5finshz2.json', 'init=/tmp/tmpy5nrbzj0/ihdkfv5p.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelw3udpsyn/prophet_model-20231030022201.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:22:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/iz15moax.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/457upxgz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41112', 'data', 'file=/tmp/tmpy5nrbzj0/iz15moax.json', 'init=/tmp/tmpy5nrbzj0/457upxgz.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model20z76_5s/prophet_model-20231030022201.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:22:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:22:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:22:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/3ny3mfc8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/yab7yr2l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/5h7_1taf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9688', 'data', 'file=/tmp/tmpy5nrbzj0/3ny3mfc8.json', 'init=/tmp/tmpy5nrbzj0/5h7_1taf.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelstdvdi8b/prophet_model-20231030022202.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:22:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/53r58xeb.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86290', 'data', 'file=/tmp/tmpy5nrbzj0/yab7yr2l.json', 'init=/tmp/tmpy5nrbzj0/53r58xeb.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_model9lhcgrfv/prophet_model-20231030022202.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:22:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:22:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:22:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/1hl63kty.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/mcd7h01e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/i9deah7j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60412', 'data', 'file=/tmp/tmpy5nrbzj0/1hl63kty.json', 'init=/tmp/tmpy5nrbzj0/i9deah7j.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelv59l66cm/prophet_model-20231030022203.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:22:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpy5nrbzj0/cdzcqukb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62346', 'data', 'file=/tmp/tmpy5nrbzj0/mcd7h01e.json', 'init=/tmp/tmpy5nrbzj0/cdzcqukb.json', 'output', 'file=/tmp/tmpy5nrbzj0/prophet_modelrx58gbt3/prophet_model-20231030022203.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 02:22:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 02:22:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 02:22:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 0.014528546294596954

# %% [markdown]
# The Mean Absolute Percentage Error (MAPE) from cross-validation is 1.45% for the log-scale model with the best parameters, which is much better than the baseline model of 8.35%.

# %% [markdown]
# # Step 7: Let's Forecast

# %%
# create a future dataframe for next 30 days
future = auto_model_log.make_future_dataframe(periods=30, freq='D')

# %%
# view dataframe
future.tail()
# Out:
#             ds
# 631 2023-06-26
# 632 2023-06-27
# 633 2023-06-28
# 634 2023-06-29
# 635 2023-06-30

# %%
# make predictions
prediction = auto_model_log.predict(future)

# %%
# select the date column and the last 30 predictions which are the future predictions
pred = prediction[["ds","yhat"]].iloc[-30:]
pred.tail()
# Out:
#             ds      yhat
# 631 2023-06-26  4.926373
# 632 2023-06-27  4.929097
# 633 2023-06-28  4.935196
# 634 2023-06-29  4.940997
# 635 2023-06-30  4.944750

# %%
# rescale to original scale
pred['yhat'] = np.exp(pred['yhat'])
pred.reset_index(inplace=True, drop=True)
pred
# Out:
#            ds        yhat
# 0  2023-06-01  125.428726
# 1  2023-06-02  125.776592
# 2  2023-06-03  123.108661
# 3  2023-06-04  123.466824
# 4  2023-06-05  126.746251
# 5  2023-06-06  126.881818
# 6  2023-06-07  127.465114
# 7  2023-06-08  128.041126
# 8  2023-06-09  128.392276
# 9  2023-06-10  125.685981
# 10 2023-06-11  126.103370
# 11 2023-06-12  129.538823
# 12 2023-06-13  129.778097
# 13 2023-06-14  130.496054
# 14 2023-06-15  131.222565
# 15 2023-06-16  131.729400
# 16 2023-06-17  129.094393
# 17 2023-06-18  129.673331
# 18 2023-06-19  133.363305
# 19 2023-06-20  133.749432
# 20 2023-06-21  134.616791
# 21 2023-06-22  135.475792
# 22 2023-06-23  136.086179
# 23 2023-06-24  133.416935
# 24 2023-06-25  134.049608
# 25 2023-06-26  137.878527
# 26 2023-06-27  138.254574
# 27 2023-06-28  139.100376
# 28 2023-06-29  139.909618
# 29 2023-06-30  140.435791

# %% [markdown]
# ### Get actual values for June 2023 of Google stock

# %%
# Data start date
forecast_start_date = '2023-06-01'

# Data end date
forecast_end_date = '2023-06-30' # yfinance excludes the end date, so we need to add one day to the last day of data

# %%
# Pull close data from Yahoo Finance for the list of tickers
ticker_list = ['GOOG']
data = yf.download(ticker_list, start=forecast_start_date, end=forecast_end_date)[['Close']]

# Change column names
data = data.reset_index()
data.columns = ['ds', 'y']

# Take a look at the data
data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#           ds           y
# 0 2023-06-01  124.370003
# 1 2023-06-02  125.230003
# 2 2023-06-05  126.629997
# 3 2023-06-06  127.910004
# 4 2023-06-07  122.940002

# %%
final = pred.merge(data, on='ds', how='left')
final.dropna(subset=['y'], inplace=True)
final

# %%
from matplotlib import pyplot as plt

# Plotting the data using matplotlib
plt.plot(final.index, final['y'], label='Actual')
plt.plot(final.index, final['yhat'], label='Predicted')
plt.title("actual vs predicted")
plt.xlabel('Date')
plt.ylabel('price')
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.legend(loc='upper left')  # Display the legend
plt.show()

# %% [markdown]
# You will observe the predictions are so off. It is essential to note that predicting stock prices is a complex task. It definately cannot be done with single variable alone.
#
# If you data has a seasonality and a pattern to it, you should be able to make good forecasts.

# %% [markdown]
# # Put All Code Together

# %%
#--------------------------------------------#
# Step 1: Install and Import Libraries
#--------------------------------------------#

# Install libraries
# !pip install yfinance prophet

# Data processing
import pandas as pd
import numpy as np

# Get time series data
import yfinance as yf

# Prophet model for time series forecast
from prophet import Prophet

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Hyperparameter tuning
import itertools
from prophet.diagnostics import cross_validation, performance_metrics

#--------------------------------------------#
# Step 2: Pull Data
#--------------------------------------------#

# Data start date
start_date = '2020-01-02'

# Data end date
end_date = '2022-01-01' # yfinance excludes the end date, so we need to add one day to the last day of data

# Pull close data from Yahoo Finance for the list of tickers
ticker_list = ['GOOG']
data = yf.download(ticker_list, start=start_date, end=end_date)[['Close']]

# Change column names
data = data.reset_index()
data.columns = ['ds', 'y']

# Take a look at the data
data.head()

# Data information
data.info()

# Visualize data using seaborn
sns.set(rc={'figure.figsize':(12,8)})
sns.lineplot(x=data['ds'], y=data['y'])
plt.legend(['Google'])

#--------------------------------------------#
# Step 3: Baseline Model Using Default Hyperparameters
#--------------------------------------------#

# Initiate the model
baseline_model = Prophet()

# Fit the model on the training dataset
baseline_model.fit(data)

# Cross validation
baseline_model_cv = cross_validation(model=baseline_model, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")
baseline_model_cv.head()

# Model performance metrics
baseline_model_p = performance_metrics(baseline_model_cv, rolling_window=1)
baseline_model_p.head()

# Get the performance value
baseline_model_p['mape'].values[0]

#--------------------------------------------#
# Step 4: Models with Manual Hyperparameter Changes
#--------------------------------------------#

# Initiate the model
manual_model = Prophet(changepoint_range=0.9)

# Fit the model on the training dataset
manual_model.fit(data)

# Cross validation
manual_model_cv = cross_validation(manual_model, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")

# Model performance metrics
manual_model_p = performance_metrics(manual_model_cv, rolling_window=1)
manual_model_p['mape'].values[0]

# COVID time window
COVID = pd.DataFrame({
    'holiday': 'COVID',
    'ds': pd.to_datetime(['2020-03-15']),
    'lower_window': -15,
    'upper_window': 15,
})

# Super Bowl time window
superbowl = pd.DataFrame({
    'holiday': 'superbowl',
    'ds': pd.to_datetime(['2020-02-02', '2021-02-07']),
    'lower_window': -7,
    'upper_window': 1,
})

# Combine all events
events = pd.concat((COVID, superbowl))

# Take a look at the events data
events

# Add special events
manual_model = Prophet(holidays=events)

# Fit the model on the training dataset
manual_model.fit(data)

# Cross validation
manual_model_cv = cross_validation(manual_model, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")

# Model performance metrics
manual_model_p = performance_metrics(manual_model_cv, rolling_window=1)
manual_model_p['mape'].values[0]

#--------------------------------------------#
# Step 5: Automatic Hyperparameter Tuning
#--------------------------------------------#

# Set up parameter grid
param_grid = {
    'changepoint_prior_scale': [0.001, 0.05, 0.08, 0.5],
    'seasonality_prior_scale': [0.01, 1, 5, 10, 12],
    'seasonality_mode': ['additive', 'multiplicative']
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]

# Create a list to store MAPE values for each combination
mapes = []

# Use cross validation to evaluate all parameters
for params in all_params:
    # Fit a model using one parameter combination
    m = Prophet(**params).fit(data)
    # Cross-validation
    df_cv = cross_validation(m, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")
    # Model performance
    df_p = performance_metrics(df_cv, rolling_window=1)
    # Save model performance metrics
    mapes.append(df_p['mape'].values[0])

# Tuning results
tuning_results = pd.DataFrame(all_params)
tuning_results['mape'] = mapes

# Find the best parameters
best_params = all_params[np.argmin(mapes)]
print(best_params)

# Fit the model using the best parameters
auto_model = Prophet(changepoint_prior_scale=best_params['changepoint_prior_scale'],
                     seasonality_prior_scale=best_params['seasonality_prior_scale'],
                     seasonality_mode=best_params['seasonality_mode'])

# Fit the model on the training dataset
auto_model.fit(data)

# Cross validation
auto_model_cv = cross_validation(auto_model, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")

# Model performance metrics
auto_model_p = performance_metrics(auto_model_cv, rolling_window=1)

auto_model_p['mape'].values[0]

#--------------------------------------------#
# Step 6: Automatic Hyperparameter Tuning using Log Data
#--------------------------------------------#

# Create a copy of the data
data_log = data.copy()

# Create the log scale data by taking the natual log of the stock prices.
data_log['y_log'] = np.log(data['y'])

# Delete the stock price and rename the log scale stock price to y
data_log = data_log.drop('y', axis=1).rename(columns={'y_log': 'y'})

# Take a look at the data
data_log.head()

# Parameter grid
param_grid = {
    'changepoint_prior_scale': [0.001, 0.05, 0.08, 0.5],
    'seasonality_prior_scale': [0.01, 1.0, 5, 10, 12],
    'seasonality_mode': ['additive', 'multiplicative']
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
mapes = []  # Store the MAPEs for each params here

# Use cross validation to evaluate all parameters
for params in all_params:
    # Fit a model using one parameter combination
    m = Prophet(**params).fit(data_log)
    # Cross-validation
    df_cv = cross_validation(m, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")
    # Model performance
    df_p = performance_metrics(df_cv, rolling_window=1)
    # Save model performance metrics
    mapes.append(df_p['mape'].values[0])

# Tuning results
best_params = all_params[np.argmin(mapes)]

# Best parameters
print(best_params)

# Train model using best parameters
auto_model_log = Prophet(changepoint_prior_scale=best_params['changepoint_prior_scale'],
                     seasonality_prior_scale=best_params['seasonality_prior_scale'],
                     seasonality_mode=best_params['seasonality_mode'])

# Fit the model on the training dataset
auto_model_log.fit(data_log)

# Cross validation
auto_model_log_cv = cross_validation(auto_model_log, initial='200 days', period='30 days', horizon = '30 days', parallel="processes")

# Model performance metrics
auto_model_log_p = performance_metrics(auto_model_log_cv, rolling_window=1)
auto_model_log_p['mape'].values[0]
